# %% [markdown]
# # Processamento dos slides
#
# Primeiramente, a conversão é de PPTX para TXT. É possível pular essa etapa e ir diretamente para JSON, mas a conversão para TXT é útil para visualização e depuração.

# %%
from pptx import Presentation
import glob

files = glob.glob("slides_adapt\\*.pptx")
# files = ["slides\\Louvores Avulsos CIAs 2022 - COM ANIMAÇÃO.pptx"]
# files.remove("slides\\01.COLETÂNEA_IGREJAS_2022_TV-16.9.pptx")
# files.remove("slides\\03.COLETÂNEA DE CIAS_2021 TV.pptx")
files
# Out:
# []

# %%
from pptx.enum.shapes import MSO_SHAPE_TYPE

for file in files:
    new_file = "slides_txt\\" + file.split("\\")[1] + ".txt"

    f = open(new_file, "w")

    prs = Presentation(file)
    for i, slide in enumerate(prs.slides):

        f.write(f"\nSLIDE_{i}\n")

        for shape in slide.shapes:
            f.write(f"SHAPE_{shape.shape_type}")

            if shape.shape_type == MSO_SHAPE_TYPE.AUTO_SHAPE:
                f.write(f"_AUTO_SHAPE_{shape.auto_shape_type}\n")
                f.write(f"HEIGHT_{shape.height}\n")
                f.write(f"TOP_{shape.top}\n")

            if hasattr(shape, "text"):
                f.write(f"\nSTART_TEXT\n{shape.text}\nEND_TEXT\n")
            
            f.write("\n")

        for shape in slide.shapes:
            if hasattr(shape, "text"):
                if shape.text.lower() == "índice":
                    f.write("\n__END__\n")

    f.close()

# %% [markdown]
# # Processamento do texto

# %%
files_txt = glob.glob("slides_txt\\*.txt")
files_txt
# Out:
# ['slides_txt\\01.COLETANEA_IGREJAS_2022_TV-16.9_ADAPT.pptx.txt',
#  'slides_txt\\03.COLETÂNEA DE CIAS_2021 TV_ADAPT.pptx.txt',
#  'slides_txt\\Louvores Avulsos CIAs 2022 - COM ANIMAÇÃO_ADAPT.pptx.txt',
#  'slides_txt\\LOUVORES AVULSOS_Rev_31.12.22_ADAPT.pptx.txt']

# %%
import re
import json

auto_shape_pattern = r"_AUTO_SHAPE_([A-Z_]+)"
shape_pattern = r"SHAPE_([A-Z_]+)"

for file_txt in files_txt:
    praises = []
    with open(file_txt, "r") as f:
        text = f.read()
    
    for praise in text.split("__END__"):
        praise_struc = {}
        praise_struc["slides"] = []

        for slide in praise.split("SLIDE_"):
            slide_struc = {}
            slide_num = slide.split("\n")[0].strip()
            if not slide_num:
                continue

            slide_struc["slide"] = slide_num
            slide_struc["shapes"] = []

            for shape in slide.split("\nSHAPE_"):
                record_line = False
                text_inside = ""
                shapes_struc = {}

                for line in shape.split("\n"):
                    if "SHAPE_" in line:
                        match = re.search(auto_shape_pattern, line)
                        auto_shape = match.group(1)

                        shapes_struc["auto_shape"] = auto_shape
                        shapes_struc["shape"] = "AUTO_SHAPE"

                    if "HEIGHT_" in line:
                        height = line.split("_")[1]
                        shapes_struc["height"] = int(height)
                    if "TOP_" in line:
                        top = line.split("_")[1]
                        shapes_struc["top"] = int(top)

                    if "END_TEXT" in line:
                        record_line = False

                    if record_line:
                        text_inside += line + "\n"
                    else:
                        if text_inside:
                            shapes_struc["text"] = text_inside.strip()

                    if "START_TEXT" in line:
                        text_inside = ""
                        record_line = True

                if shapes_struc:
                    slide_struc["shapes"].append(shapes_struc)

            praise_struc["slides"].append(slide_struc)

        # pegar nome/numero do hino antes de salvar
        praises.append(praise_struc)

    new_file = "slides_json\\" + file_txt.split("\\")[1] + ".json"
    with open(new_file, "w") as f:
        f.write(json.dumps(praises))

# %% [markdown]
# # Processamento do JSON

# %%
def get_texts(d):
    if isinstance(d, dict):
        for k, v in d.items():
            if k == "text":
                yield v
            else:
                yield from get_texts(v)
    elif isinstance(d, list):
        for v in d:
            yield from get_texts(v)

# %%
import json

with open("slides_json\\LOUVORES AVULSOS_Rev_31.12.22_ADAPT.pptx.txt.json", "r") as f:
    praises = json.load(f)

praises
# Out:
# [{'slides': [{'slide': '0',
#     'shapes': [{'text': 'SHEKINAH'},
#      {'text': 'CORO\nÓ SENHOR, A TI CLAMO\nQUE NOS MOSTRES A TUA SHEKINAH;\nCOM TUA GLÓRIA ENCHE ESTE LUGAR,\nCOM TUA PRESENÇA, A TUA SHEKINAH.'}]},
#    {'slide': '1',
#     'shapes': [{'text': 'SENHOR, SEI QUE ME CONHECES,\nQUERO ANDAR EM TEU CAMINHO\nE ENCONTRAR O TEU FAVOR.'}]},
#    {'slide': '2',
#     'shapes': [{'text': 'SENHOR, SÓ TUA PRESENÇA \nPODE ME FAZER DESCANSAR, \nSE NÃO FORES COMIGO EU NÃO PROSSEGUIREI,\nSE ANDARES COMIGO O MUNDO SABERÁ QUE \nTE ENCONTREI, POIS DESTE MUNDO EU ME SEPAREI.'}]},
#    {'slide': '3',
#     'shapes': [{'text': 'CORO\nÓ SENHOR, A TI CLAMO\nQUE NOS MOSTRES A TUA SHEKINAH;\nCOM TUA GLÓRIA ENCHE ESTE LUGAR,\nCOM TUA PRESENÇA, A TUA SHEKINAH. \n\nINSTRUMENTOS'},
#      {'auto_shape': 'RIGHT_BRACE',
#       'shape': 'AUTO_SHAPE',
#       'height': 2946754,
#       'top': 1431255,
#       'text': ''},
#      {'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 587211,
#       'top': 2611026,
#       'text': 'BIS'}]},
#    {'slide': '4',
#     'shapes': [{'text': 'CORO\nÓ SENHOR, A TI CLAMO\nQUE NOS MOSTRES A TUA SHEKINAH;\nCOM TUA GLÓRIA ENCHE ESTE LUGAR,\nCOM TUA PRESENÇA, A TUA SHEKINAH.\n\nFINAL: SHEKINAH, SHEKINAH!'},
#      {'text': 'Índice'}]}]},
#  {'slides': [{'slide': '5',
#     'shapes': [{'text': 'ESSAS LÁGRIMAS QUE ESCORREM DOS TEUS OLHOS\nSÓ JESUS É QUE PODE ENXUGÁ-LAS,\nSE TU VIVES TÃO SOZINHO, SEM PAZ, SEM AMOR,\nCRISTO QUER SER SEU AMIGO;'},
#      {'text': 'Torre forte'}]},
#    {'slide': '6',
#     'shapes': [{'text': 'ELE JÁ LEVOU SOBRE SI \nNOSSAS DORES E OS NOSSOS PECADOS,\nFOI COM SANGUE INOCENTE \nQUE NÓS FOMOS COMPRADOS,\nHOJE SOMOS PARTE DO REINO DE DEUS.'}]},
#    {'slide': '7',
#     'shapes': [{'text': 'CORO\nTORRE FORTE (TORRE FORTE),\nDEUS CONOSCO (DEUS CONOSCO),\nPODEROSO EM OBRAS, PRÍNCIPE DOS EXÉRCITOS;\nO SENHOR SEMPRE VENCEU,\nNELE NÃO HÁ DERROTAS, \nELE É REI SOBRE TODOS OS REIS\n\nINSTRUMENTOS'}]},
#    {'slide': '8',
#     'shapes': [{'text': 'VEJO CRISTO SOBRE AS NUVENS TRIUNFANTE,\nEIS O BRADO DE VITÓRIA, NÓS VENCEMOS!\nOUÇO O TOQUE DA TROMBETA, \nA IGREJA VAI SUBINDO,\nANJOS E ARCANJOS NOS ESPERAM NO CÉU;'}]},
#    {'slide': '9',
#     'shapes': [{'text': 'ALELUIA, NÓS CHEGAMOS AO FIM, \nOS REMIDOS QUE EM DEUS CONFIARAM,\nHÁ NO CÉU ALEGRIA, ALTO SOM DE LOUVOR,\nTODOS BENDIZENDO AO FILHO DE DEUS.'}]},
#    {'slide': '10',
#     'shapes': [{'text': 'CORO\nTORRE FORTE (TORRE FORTE),\nDEUS CONOSCO (DEUS CONOSCO),\nPODEROSO EM OBRAS, PRÍNCIPE DOS EXÉRCITOS;\nO SENHOR SEMPRE VENCEU,\nNELE NÃO HÁ DERROTAS, \nELE É REI SOBRE TODOS OS REIS'}]},
#    {'slide': '11',
#     'shapes': [{'text': 'FINAL:\nO SENHOR SEMPRE VENCEU, \nNELE NÃO HÁ DERROTAS, \nELE É REI SOBRE TODOS OS REIS,\nREI SOBRE TODOS OS REIS.'},
#      {'text': 'Índice'}]}]},
#  {'slides': [{'slide': '12',
#     'shapes': [{'text': 'VARÃO DE GUERRA É O SENHOR'},
#      {'text': 'VARÃO DE GUERRA É O SENHOR \nQUE VAI À FRENTE DO SEU POVO\nNAS PELEJAS DA ALMA, NAS PROVAÇÕES\nNAS LUTAS CONTRA OS NOSSOS ADVERSÁRIOS.'}]},
#    {'slide': '13',
#     'shapes': [{'text': 'VARÃO DE GUERRA É O SENHOR \nQUE ERGUE A SUA ESPADA \nE COM LABAREDAS DE FOGO\nTOCA NOS SEUS MINISTROS \nE OS TORNA CAPAZES PARA AS PELEJAS.'}]},
#    {'slide': '14',
#     'shapes': [{'text': 'ESTE É O MEU DEUS, \nSOBERANO EM FORÇA E PODER, \nO ÚNICO QUE SE ASSENTA \nNO TRONO DA GLÓRIA E QUE REINARÁ\nETERNAMENTE;'}]},
#    {'slide': '15',
#     'shapes': [{'text': 'ESTE É O MEU DEUS, \nSOBERANO EM FORÇA E PODER, \nJUSTO E CUMPRIDOR DA SUA PALAVRA, \nQUE NOS PROMETEU UM REI, JESUS,\nPARA REINAR SOBRE NÓS NA CIDADE SANTA\n\nFINAL: ETERNAMENTE.'},
#      {'text': 'Índice'}]}]},
#  {'slides': [{'slide': '16',
#     'shapes': [{'text': 'AINDA HÁ TEMPO'},
#      {'text': 'COMO É FORTE OUVIR COMO SERÁ O FIM; \nO MOMENTO CHEGARÁ, \nO CLAMOR DA MEIA-NOITE SE OUVIRÁ.\n\nA IGREJA FIEL PREPARADA ESTÁ \nE A IGREJA INFIEL, \nSUA OPORTUNIDADE ACABARÁ.'}]},
#    {'slide': '17',
#     'shapes': [{'text': 'AINDA HÁ TEMPO, \nJESUS CRISTO NÃO VOLTOU, \nAINDA HÁ TEMPO \nDO SEU SONO DESPERTAR. \n\nAINDA HÁ TEMPO, \nTEMPO DE SE ARREPENDER, \nTEMPO DE BUSCAR A DEUS, \nDE BATER À PORTA E ELA SE ABRIRÁ'}]},
#    {'slide': '18',
#     'shapes': [{'text': 'AINDA HÁ TEMPO DO AZEITE IR COMPRAR, \nAINDA HÁ TEMPO, TEMPO DE SANTIFICAR; AINDA HÁ TEMPO DA CANDEIA SE ENCHER, DO ESPOSO ENCONTRAR E COM ELE, \nPARA AS BODAS DO CORDEIRO, ENTRAR.'}]},
#    {'slide': '19',
#     'shapes': [{'text': 'AINDA HÁ TEMPO, \nJESUS CRISTO NÃO VOLTOU, \nAINDA HÁ TEMPO \nDO SEU SONO DESPERTAR. \n\nAINDA HÁ TEMPO, \nTEMPO DE SE ARREPENDER, \nTEMPO DE BUSCAR A DEUS, \nDE BATER À PORTA E ELA SE ABRIRÁ'}]},
#    {'slide': '20',
#     'shapes': [{'text': 'AINDA HÁ TEMPO DO AZEITE IR COMPRAR, \nAINDA HÁ TEMPO, TEMPO DE SANTIFICAR; AINDA HÁ TEMPO DA CANDEIA SE ENCHER, DO ESPOSO ENCONTRAR E COM ELE, \nPARA AS BODAS DO CORDEIRO, ENTRAR.\n\nFINAL: AINDA HÁ TEMPO'},
#      {'text': 'Índice'}]}]},
#  {'slides': [{'slide': '21',
#     'shapes': [{'text': 'UMA VOZ MANSA E DELICADA\nSINTA AGORA A MINHA PAZ EM TEU CORAÇÃO \nSEI PORQUE ESTÁS AQUI\nPENSAS QUE EU NÃO TE VI\nSAI DA ESCURIDÃO EU VOU TIRAR \nO MEDO DO TEU CORAÇÃO'},
#      {'text': 'UMA VOZ MANSA E DELICADA SINTA AGORA'}]},
#    {'slide': '22',
#     'shapes': [{'text': 'PENSAS ESTAR SÓ E OLHAS AO TEU REDOR\nSEI QUE HÁ MUITOS QUE ME DEIXARAM \nDESTRUIRAM MEUS ALTARES\nDESPREZARAM A PROFECIA DO TEU DEUS'}]},
#    {'slide': '23',
#     'shapes': [{'text': 'EU QUERO TE DIZER QUE EU LIVREI SALVEI\nTODOS QUE NÃO ME NEGARAM\nJOELHOS QUE NÃO SE DOBRARAM'},
#      {'text': ''},
#      {'text': 'BIS'}]},
#    {'slide': '24',
#     'shapes': [{'text': 'SEU FIM NÃO É AQUI\nVOCÊ VAI PROSSEGUIR\nPOIS GRANDES COISAS SIM \nTU VIVERÁS POR MIM'}]},
#    {'slide': '25',
#     'shapes': [{'text': 'UMA VOZ MANSA E DELICADA\nSINTA AGORA A MINHA PAZ EM TEU CORAÇÃO \nSEI PORQUE ESTÁS AQUI\nPENSAS QUE EU NÃO TE VI\nSAI DA ESCURIDÃO EU VOU TIRAR \nO MEDO DO TEU CORAÇÃO'}]},
#    {'slide': '26',
#     'shapes': [{'text': 'PENSAS ESTAR SÓ E OLHAS AO TEU REDOR\nSEI QUE HÁ MUITOS QUE ME DEIXARAM \nDESTRUIRAM MEUS ALTARES\nDESPREZARAM A PROFECIA DO TEU DEUS'}]},
#    {'slide': '27',
#     'shapes': [{'text': 'EU QUERO TE DIZER QUE EU LIVREI SALVEI\nTODOS QUE NÃO ME NEGARAM\nJOELHOS QUE NÃO SE DOBRARAM'},
#      {'text': ''},
#      {'text': 'BIS'}]},
#    {'slide': '28',
#     'shapes': [{'text': 'SEU FIM NÃO É AQUI\nVOCÊ VAI PROSSEGUIR\nPOIS GRANDES COISAS SIM \nTU VIVERÁS POR MIM'},
#      {'text': ''},
#      {'text': 'BIS'},
#      {'text': 'Índice'}]}]},
#  {'slides': [{'slide': '29',
#     'shapes': [{'text': 'EM CAMINHOS DE DOR'},
#      {'text': 'EM CAMINHOS DE DOR EU ANDAVA, \nEM DESOBEDIÊNCIA AO SENHOR; \nEU ME ASSENTAVA E CHORAVA, \nME LEMBRANDO COMO EU ERA FELIZ. \nQUEM JÁ FOI ESCRAVO UM DIA, \nSABE QUE NÃO HÁ ALEGRIA \nEM CANTAR LOUVORES DISTANTE, \nDISTANTE DA CASA DO PAI.'}]},
#    {'slide': '30',
#     'shapes': [{'text': 'COMO EU PODERIA CANTAR ALI?\nPOIS TU ÉS MINHA MAIOR ALEGRIA;\nSE NÃO FOR PRA TI, PRA NINGUÉM MAIS SERÁ.\nTUA PRESENÇA, Ó DEUS, QUERO TODOS OS DIAS!\nMEU LOUVOR É SÓ PRA TI, \nSÓ PRA TI!'}]},
#    {'slide': '31',
#     'shapes': [{'text': 'HAVERÁ O DIA DA VITÓRIA, A VITÓRIA FINAL,\nQUANDO SERÁ DESTRUÍDO E ESQUECIDO O MAL,\nO INIMIGO DO SENHOR, AQUELE QUE AOS HOMENS TROUXE TANTA DOR, TANTA DOR.\nHOJE EU CANTO AO SENHOR, \nVOLTEI, NÃO ME ESQUECEREI \nQUE É, SENHOR, NA TUA PRESENÇA, \nO LUGAR DE ONDE EU NÃO MAIS SAIREI!'}]},
#    {'slide': '32',
#     'shapes': [{'text': 'COMO EU PODERIA CANTAR ALI?\nPOIS TU ÉS MINHA MAIOR ALEGRIA;\nSE NÃO FOR PRA TI, PRA NINGUÉM MAIS SERÁ.\nTUA PRESENÇA, Ó DEUS, QUERO TODOS OS DIAS!\nMEU LOUVOR É SÓ PRA TI, \nSÓ PRA TI!'}]},
#    {'slide': '33',
#     'shapes': [{'text': 'HAVERÁ O DIA DA VITÓRIA, A VITÓRIA FINAL,\nQUANDO SERÁ DESTRUÍDO E ESQUECIDO O MAL,\nO INIMIGO DO SENHOR, AQUELE QUE AOS HOMENS TROUXE TANTA DOR, TANTA DOR.\nHOJE EU CANTO AO SENHOR, \nVOLTEI, NÃO ME ESQUECEREI \nQUE É, SENHOR, NA TUA PRESENÇA, \nO LUGAR DE ONDE EU NÃO MAIS SAIREI!'}]},
#    {'slide': '34',
#     'shapes': [{'text': 'FINAL: \nQUE É, SENHOR, NA TUA PRESENÇA, \nO LUGAR DE ONDE EU NÃO MAIS SAIREI!'},
#      {'text': 'Índice'}]}]},
#  {'slides': [{'slide': '35',
#     'shapes': [{'text': 'DE TANTAS COISAS \nQUE ANDEI FAZENDO,\nDE QUASE TODAS ME ARREPENDI.\nMAS HOUVE UMA ESPECIAL,\nFOI A MAIS CERTA QUE ESCOLHI.'},
#      {'text': 'A MELHOR COISA'}]},
#    {'slide': '36',
#     'shapes': [{'text': 'CORO\nA MELHOR COISA QUE EU JÁ FIZ\nEM TODA A MINHA VIDA, \nPOR ISSO SOU FELIZ EM \nACEITAR JESUS, SINCERAMENTE FOI\nA MELHOR COISA QUE EU JÁ FIZ.'}]},
#    {'slide': '37',
#     'shapes': [{'text': 'COISAS ERRADAS ANDEI FAZENDO\nNA CONDIÇÃO DE PECADOR,\nMAS QUANDO ACHEI-ME DESFALECENDO,\nTOMEI A DECISÃO QUE ME SALVOU.'}]},
#    {'slide': '38',
#     'shapes': [{'text': 'CORO (2X)\nA MELHOR COISA QUE EU JÁ FIZ\nEM TODA A MINHA VIDA, \nPOR ISSO SOU FELIZ EM \nACEITAR JESUS, SINCERAMENTE FOI\nA MELHOR COISA QUE EU JÁ FIZ.'},
#      {'text': 'Índice'}]}]},
#  {'slides': [{'slide': '39',
#     'shapes': [{'text': 'BARNABÉ, HOMEM DE DEUS'},
#      {'text': 'NÃO FICA BEM A GENTE PASSAR BEM E O OUTRO CARESTIA, AINDA MAIS QUANDO SE SABE O QUE FAZER E NÃO SE FAZ. COMO FRUTO DO AMOR DE CRISTO, FRUTO DO SEU COMPROMISSO, VENDEU UM HOMEM O QUE TINHA E REPARTIU.'}]},
#    {'slide': '40',
#     'shapes': [{'text': 'CORO\nERA SEU NOME BARNABÉ, NATURAL DE CHIPRE,\nTAMBÉM CHAMADO DE JOSÉ DA CONSOLAÇÃO,\nHOMEM BOM E PIEDOSO, CHEIO DE TEMOR E FÉ,\nHOMEM DE DEUS.'}]},
#    {'slide': '41',
#     'shapes': [{'text': 'E QUANDO SAULO CONVERTEU-SE A CRISTO LHE FALTOU AMIGO,ALGUÉM QUE FOSSE COMPANHEIRO,\nFONTE DE CONSOLO E ABRIGO. COMO FRUTO DO AMOR DE CRISTO, FRUTO DO SEU COMPROMISSO, FOI UM HOMEM PROCURÁ-LO, DANDO-LHE A MÃO.'}]},
#    {'slide': '42',
#     'shapes': [{'text': 'CORO\nERA SEU NOME BARNABÉ, NATURAL DE CHIPRE,\nTAMBÉM CHAMADO DE JOSÉ DA CONSOLAÇÃO,\nHOMEM BOM E PIEDOSO, CHEIO DE TEMOR E FÉ,\nHOMEM DE DEUS.'}]},
#    {'slide': '43',
#     'shapes': [{'text': 'E QUANDO A IGREJA SE ESPALHOU POR TODO CANTO QUE HAVIA, POR PROVIDÊNCIA, SIM,\nPOR MÃO DE DEUS CHEGOU A ANTIOQUIA.\nPRECISANDO DE UM PASTOR DE ALMAS, \nMESMO DE UM PASTOR DE HOMENS, FORAM PROCURAR AQUELE QUE DEUS PREPAROU.'}]},
#    {'slide': '44',
#     'shapes': [{'text': 'CORO\nERA SEU NOME BARNABÉ, NATURAL DE CHIPRE,\nTAMBÉM CHAMADO DE JOSÉ DA CONSOLAÇÃO,\nHOMEM BOM E PIEDOSO, CHEIO DE TEMOR E FÉ,\nHOMEM DE DEUS.'},
#      {'text': 'Índice'}]}]},
#  {'slides': [{'slide': '45',
#     'shapes': [{'text': 'COMO AGRADECER, PELO BEM \nQUE TENS FEITO A MIM? \nQUE VEM DEMONSTRAR QUANTO \nAMOR TU TENS, Ó DEUS, POR MIM;'},
#      {'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 794805,
#       'top': 348418,
#       'text': 'COMO AGRADECER (MEU TRIBUTO)'}]},
#    {'slide': '46',
#     'shapes': [{'text': 'AS VOZES DE MILHÕES DE ANJOS, \nNÃO PODERIAM EXPRESSAR, \nA GRATIDÃO DO MEU PEQUENO\nSER, QUE SÓ PERTENCE A TI.'}]},
#    {'slide': '47',
#     'shapes': [{'text': 'A DEUS DEMOS GLÓRIA (3X)\nQUE POR NÓS TANTO FEZ;\nFOI NA CRUZ QUE SALVOU-ME,\nSEU PODER RESTAUROU-ME,\nA DEUS DEMOS GLÓRIA, \nQUE POR NÓS TANTO FEZ.'}]},
#    {'slide': '48',
#     'shapes': [{'text': 'FOI NA CRUZ QUE SALVOU-ME,\nSEU PODER RESTAUROU-ME,\nA DEUS DEMOS GLÓRIA, \nQUE POR NÓS TANTO FEZ.'}]},
#    {'slide': '49',
#     'shapes': [{'text': 'QUERO VIVER AQUI \nPARA ADORAR-TE, MEU SENHOR,\nE SE SURGIR UM LOUVOR\nAO CALVÁRIO SEJA, SIM, SEJA, SIM.'}]},
#    {'slide': '50',
#     'shapes': [{'text': 'FOI NA CRUZ QUE SALVOU-ME,\nSEU PODER RESTAUROU-ME,\nA DEUS DEMOS GLÓRIA, \nQUE POR NÓS TANTO FEZ.'},
#      {'text': 'Índice'}]}]},
#  {'slides': [{'slide': '51',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 3456384,
#       'top': 1935311,
#       'text': 'TEU SANTO FILHO, SEM PECAR\nFOI ENVIADO PRA LEVAR\nUM PESO QUE ERA TODO MEU\nE SE TORNAR CORDEIRO DE DEUS.'},
#      {'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 586581,
#       'top': 415343,
#       'text': 'CORDEIRO DE DEUS'}]},
#    {'slide': '52',
#     'shapes': [{'text': 'O SEU PRESENTE DE AMOR\nFOI REJEITADO PELOS SEUS,\nHUMILDE REI, NADA FALOU\nE ASSIM SE FEZ CORDEIRO DE DEUS.'}]},
#    {'slide': '53',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 4065334,
#       'top': 1182345,
#       'text': 'CORO\nCORDEIRO DE DEUS, TÃO PURO ÉS\nVOU TE ADORAR E TE EXALTAR\nCOM SANGUE VEM LAVAR MEU SER\nMEU CRISTO ÉS CORDEIRO DE DEUS.'}]},
#    {'slide': '54',
#     'shapes': [{'text': 'PERDIDO ESTAVA SEM SABER,\nMAS ME ATRAÍSTE A TEU SER\nE HOJE SOU UM SERVO TEU\nPRA TEU LOUVOR, \nCORDEIRO DE DEUS.'}]},
#    {'slide': '55',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 4065334,
#       'top': 1287239,
#       'text': 'CORO\nCORDEIRO DE DEUS, TÃO PURO ÉS\nVOU TE ADORAR E TE EXALTAR\nCOM SANGUE VEM LAVAR MEU SER\nMEU CRISTO ÉS CORDEIRO DE DEUS.'},
#      {'text': ''},
#      {'text': 'BIS'},
#      {'text': 'Índice'}]}]},
#  {'slides': [{'slide': '56',
#     'shapes': [{'text': 'DESCANSA, Ó ALMA, \nEIS O SENHOR AO LADO; \nPACIENTE LEVA, \nE SEM QUEIXAR-TE, A CRUZ;'},
#      {'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 586581,
#       'top': 351135,
#       'text': 'DESCANSA, Ó ALMA'}]},
#    {'slide': '57',
#     'shapes': [{'text': 'DEIXA O SENHOR TOMAR \nDE TI CUIDADO,\nÉ IMUTÁVEL TEU FIEL JESUS!\nPROSSEGUE, Ó ALMA, \nO AMIGO CELESTIAL PROTEGERÁ \nTEUS PASSOS NO ESPINHAL!'}]},
#    {'slide': '58',
#     'shapes': [{'text': 'PROSSEGUE, Ó ALMA, \nO TRILHO É ESTREITO E ESCURO,\nMAS, NO PASSADO DEUS \nGUIOU-TE ASSIM!\nCONFIA AGORA A DEUS O TEU FUTURO,\nE O QUE É MISTÉRIO HÁ DE \nACLARAR-SE ENFIM,\nCONFIA, Ó ALMA, A SUA MANSA \nVOZ AINDA ACALMA O VENTO \nE O MAR FEROZ!'}]},
#    {'slide': '59',
#     'shapes': [{'text': 'CONFIA, Ó ALMA, \nA HORA VEM CHEGANDO!\nIRÁS COM CRISTO, O TEU SENHOR, \nMORAR, SEM DOR, NEM MÁGOAS,\nGOZARÁS, CANTANDO \nAS ALEGRIAS DO CELESTE LAR!\nDESCANSA, Ó ALMA, \nAGORA HÁ PRANTO E DOR, \nDEPOIS O GOZO, A PAZ, \nO CÉU DE AMOR!'},
#      {'text': 'Índice'}]}]},
#  {'slides': [{'slide': '60',
#     'shapes': [{'text': 'DEUS, DEUS, DEUS\nSANTO É TEU NOME, SENHOR!\nÀ TUA IMAGEM FEITOS,\nA TI LOUVORES ENTOEMOS\nPOIS FILHOS NOS FIZESTE.'},
#      {'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 586581,
#       'top': 412626,
#       'text': 'DEUS, DEUS, DEUS'}]},
#    {'slide': '61',
#     'shapes': [{'text': 'O TEU PODER IMENSO, Ó DEUS,\nMOSTRAR-NOS VEM\nCOM GRANDE AMOR.\n\n\nGLÓRIA AO SENHOR CANTEMOS\nE SEU AMOR LOUVEMOS.\nGLÓRIA, GLÓRIA AO SENHOR!'},
#      {'text': ''},
#      {'auto_shape': 'ROUNDED_RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 556179,
#       'top': 4475476,
#       'text': 'BIS'},
#      {'text': ''},
#      {'auto_shape': 'ROUNDED_RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 556179,
#       'top': 1359247,
#       'text': 'BIS'}]},
#    {'slide': '62',
#     'shapes': [{'text': 'QUAL VIAJANTE \nEM NOITE ESCURA,\nVAI PROCURANDO A LUZ,\nASSIM MINH’ALMA\nA DEUS PROCURA,\nPOIS ELE ME CONDUZ.'}]},
#    {'slide': '63',
#     'shapes': [{'text': 'É CERTO QUE PROVADO SOU,\nPELO CAMINHO A PROSSEGUIR,\nPORÉM EU SEI QUE TU BEM PERTO ESTÁS.\nQUANDO HEI DE IR, SENHOR, NÃO SEI,\nPARA O TEU SANTO LAR,\nSINTO PORÉM TUA VOZ CHAMAR,\nEM BREVE PARTIREI.'}]},
#    {'slide': '64',
#     'shapes': [{'text': 'TUDO O QUE DEUS FIZER É BOM,\nA NOITE CLARA FICARÁ\nNO ETERNO LAR DE DEUS.\nAMÉM (5X)'},
#      {'text': 'Índice'}]}]},
#  {'slides': [{'slide': '65',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 4986895,
#       'top': 1412911,
#       'text': 'DEUS PREPAROU UMA CIDADE \nPARA SUA IGREJA FIEL.\nNESTA CIDADE NÃO HAVERÁ DOR,\nPOIS ELE NÃO PERMITIRÁ.\nSEREMOS TIRADOS DESTE \nMUNDO CRUEL, PARA \nMORARMOS COM ELE NO CÉU.'},
#      {'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 586581,
#       'top': 412626,
#       'text': 'DEUS PREPAROU'}]},
#    {'slide': '66',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 5757039,
#       'top': 858792,
#       'text': 'CORO\nEU QUERO ENTRAR NO CÉU COM JESUS,\nE CONTEMPLAR AS MANSÕES \nQUE DEUS PREPAROU.\nQUERO ANDAR NAS RUAS DE OURO\nE OUVIR A VOZ DE DEUS \nO MEU NOME CHAMAR.'}]},
#    {'slide': '67',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 4881542,
#       'top': 1302241,
#       'text': 'OUVE A VOZ DO REDENTOR, \nELE QUER HOJE SALVAR, \nQUER LIBERTAR E PERDOAR, \nTUAS FERIDAS CURAR E NÃO TARDARÁ.\nCRISTO VEM NOS BUSCAR, \nENTREGA TUA VIDA E ELE TE LEVARÁ.'}]},
#    {'slide': '68',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 5173575,
#       'top': 858792,
#       'text': 'CORO\nEU QUERO ENTRAR NO CÉU COM JESUS,\nE CONTEMPLAR AS MANSÕES \nQUE DEUS PREPAROU.\nQUERO ANDAR NAS RUAS DE OURO\nE OUVIR A VOZ DE DEUS \nO MEU NOME CHAMAR.'},
#      {'text': 'Índice'}]}]},
#  {'slides': [{'slide': '69',
#     'shapes': [{'text': 'EU NÃO POSSO FUGIR DO TEU ESPÍRITO, (SERVAS) \nNEM FICAR DISTANTE DO TEU AMOR; (VARÕES)\nSE EU SUBIR ATÉ OS CÉUS, \nSE AO ABISMO EU DESCER, \nSEI QUE ALI TU ESTÁS.'},
#      {'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 586581,
#       'top': 415343,
#       'text': 'EU NÃO POSSO FUGIR DO TEU ESPÍRITO'}]},
#    {'slide': '70',
#     'shapes': [{'text': 'MESMO SE EU TOMAR \nAS ASAS DA ALVORADA, \nTUA  MÃO AINDA ASSIM MEGUIARÁ, \nMESMO VINDO A NOITE ESCURA\nTUA LUZ BRILHARÁ, \nE COMIGO ESTARÁS.'}]},
#    {'slide': '71',
#     'shapes': [{'text': 'EU NÃO POSSO FUGIR DO TEU ESPÍRITO, (SERVAS) \nNEM FICAR DISTANTE DO TEU AMOR; (VARÕES)\nSE EU SUBIR ATÉ OS CÉUS, \nSE AO ABISMO EU DESCER, \nSEI QUE ALI TU ESTÁS.'}]},
#    {'slide': '72',
#     'shapes': [{'text': 'MESMO SE EU TOMAR \nAS ASAS DA ALVORADA, \nTUA  MÃO AINDA ASSIM MEGUIARÁ, \nMESMO VINDO A NOITE ESCURA\nTUA LUZ BRILHARÁ, \nE COMIGO ESTARÁS.'},
#      {'text': 'Índice'}]}]},
#  {'slides': [{'slide': '73',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 3079552,
#       'top': 1967416,
#       'text': 'EXPIROU! NÃO MAIS PADECE\nDE DEUS PAI O FILHO AMADO,\nMAS O SOLO SE ESTREMECE \nCOM SEU SANGUE DERRAMADO.'},
#      {'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 586581,
#       'top': 412626,
#       'text': 'EXPIROU'}]},
#    {'slide': '74',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 5758938,
#       'top': 784885,
#       'text': 'FOI ENTÃO QUE A DEUS BENDITO\nIMPLOROU O SALVADOR.\nEIS O AMOR VASTO, INFINITO, \nPELO POVO TRANSGRESSOR.\nENTREGOU A SUA VIDA! \nGRANDE PROVA DE AMOR!\nMESMO ALI CRUCIFICADO \nAMA A QUEM O CONDENOU!'}]},
#    {'slide': '75',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 4832778,
#       'top': 1278997,
#       'text': 'AOS SEUS PÉS EU VOU, ENQUANTO\nSOFRE ASSIM O CRISTO AMADO,\nPARA AO MENOS DAR-LHE O PRANTO,\nPOIS POR MIM DEU O SEU SANGUE.\nPARA AO MENOS DAR-LHE O PRANTO,\nPOIS POR MIM DEU O SEU SANGUE.'},
#      {'text': 'Índice'}]}]},
#  {'slides': [{'slide': '76',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 4812728,
#       'top': 1443063,
#       'text': 'ÉS UM REMIDO DE DEUS.\nTU ÉS UM DOS MEUS,\nÉS AQUELE A QUEM ESCOLHI.\nUM DIA OUVIU MINHA VOZ,\nA VOZ DO FILHO DE DEUS,\nA FALAR: VEM AQUI ME SERVIR.'},
#      {'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 586581,
#       'top': 351135,
#       'text': 'ÉS UM REMIDO DE DEUS'}]},
#    {'slide': '77',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 4539704,
#       'top': 1356047,
#       'text': 'SENHOR, NADA TENHO PRA TE OFERECER.\nSABES O QUE SOU, \nSABES QUEM SOU EU E O TEU \nQUERER EM MIM SERÁ O MEU PRAZER. \nTEUS MISTÉRIOS CONHECER, TUA OBRA\nREALIZAR, MINHA VIDA ENTREGAR.'}]},
#    {'slide': '78',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 4786567,
#       'top': 580583,
#       'text': 'AS LUTAS VÊM, \nMAS AS VITÓRIAS TAMBÉM VÊM.\nE O TEU AMOR É MAIS FORTE,\nE SEM ELE NÃO ESTARIA AQUI.\nCOM TEU PODER, TUA GRAÇA, TUA LUZ\nSOU UM VENCEDOR, SOU UM SERVO,\nSOU VASO A SERVIÇO DO SENHOR.'},
#      {'auto_shape': 'RIGHT_BRACE',
#       'shape': 'AUTO_SHAPE',
#       'height': 4498752,
#       'top': 855191,
#       'text': ''},
#      {'text': 'BIS'},
#      {'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 1389739,
#       'top': 5298100,
#       'text': 'FINAL: \nSOU VASO A SERVIÇO DO SENHOR.'},
#      {'text': 'Índice'}]}]},
#  {'slides': [{'slide': '79',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 3068146,
#       'top': 1967417,
#       'text': 'FINDA-SE ESTE DIA, QUE MEU PAI ME DEU,\nSOMBRA VESPERTINAS COBREM JÁ OS CÉUS,\nÓ JESUS BENDITO, SE COMIGO ESTÁS,\nEU NÃO TEMO A NOITE, VOU DORMIR EM PAZ.'},
#      {'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 586581,
#       'top': 412626,
#       'text': 'FINDA-SE ESTE DIA'}]},
#    {'slide': '80',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 3204454,
#       'top': 2115233,
#       'text': 'COM MEUS PECADOS EU TE ENTRISTECI,\nMAS PERDÃO TE PEÇO, POR AMOR DE TI.\nSOU HUMANO E FRACO, LIVRA-ME DO MAL\nE EM SOSSEGO TENHO SONO E PAZ REAL.'}]},
#    {'slide': '81',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 3214117,
#       'top': 1961554,
#       'text': 'GUARDA O MARINHEIRO NO VIOLENTO MAR\nE AO QUE SOFRE DORES, \nQUEIRAS CONFORTAR.\nAO TENTADO ESTENDE TUA MÃO SENHOR,\nMANDA AO TRISTE E AFLITO TEU CONSOLADOR.'}]},
#    {'slide': '82',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 2887781,
#       'top': 2143873,
#       'text': 'PELOS PAIS E AMIGOS, PELA SANTA LEI,\nPELO AMOR DIVINO GRAÇAS TE DAREI.\nÓ JESUS ACEITA MINHA PETIÇÃO,\nE SEGURO DURMO SEM PERTUBAÇÃO.'},
#      {'text': 'Índice'}]}]},
#  {'slides': [{'slide': '83',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 3424278,
#       'top': 1967417,
#       'text': 'GUIA-ME PELAS DUNAS DO DESERTO\nGUIA-ME SINTO O TEU AMOR BEM PERTO\nGUIA-ME PELAS RUAS DESTA VIDA\nGUIA-ME ATÉ A TERRA PROMETIDA'},
#      {'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 586581,
#       'top': 412626,
#       'text': 'GUIA-ME'}]},
#    {'slide': '84',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 4519602,
#       'top': 1376149,
#       'text': 'CORO\nGUIA-ME, DÁ-ME FORÇAS \nDE TI PRECISO TANTO ASSIM, \nUSA-ME, COMO QUISERES \nPORQUE TU ÉS PARTE DE MIM.\n\nINSTRUMENTOS'}]},
#    {'slide': '85',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 2579353,
#       'top': 2189141,
#       'text': 'Ó SENHOR, TEU CAJADO ME CONSOLA\nONDE FOR O MEU CÁLICE TRANSBORDA.\nFAZ-ME SER UM MANANCIAL DE ÁGUAS\nFAZ CORRER ÁGUAS VIVAS DE MINH’ALMA.'}]},
#    {'slide': '86',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 3104145,
#       'top': 1893507,
#       'text': 'CORO\nGUIA-ME, DÁ-ME FORÇAS \nDE TI PRECISO TANTO ASSIM, \nUSA-ME, COMO QUISERES \nPORQUE TU ÉS PARTE DE MIM.'}]},
#    {'slide': '87',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 3558793,
#       'top': 2336958,
#       'text': 'USA-ME, COMO QUISERES,\nPORQUE TU ÉS PARTE DE MIM\n\nFINAL: PARTE DE MIM.'},
#      {'text': 'Índice'}]}]},
#  {'slides': [{'slide': '88',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 4858510,
#       'top': 1382539,
#       'text': 'GRANDE É O SENHOR,\nINCLINAI-VOS TERRA HUMILDEMENTE.\nGRANDE É O SENHOR\nADORAÍ-O SEMPRE ALEGREMENTE.\nREGOZIJAI! DE CORAÇÃO!\nELE É O CRIADOR E NÓS A CRIAÇÃO.'},
#      {'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 586581,
#       'top': 412626,
#       'text': 'GRANDE É O SENHOR, INCLINAI-VOS'}]},
#    {'slide': '89',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 5492914,
#       'top': 855191,
#       'text': 'EIS QUE VEM DE SUA MÃO:\nO SOL, A LUA, ESTRELAS E PLANETAS\nJUSTO ÉS EM SUAS LEIS;\nTUFÕES ACALMAM, ONDAS OBEDECEM-NO\nSOSSEGA O MAR AO SEU MANDAR,\nMONTANHAS SE DESFARÃO,\nDESERTOS BROTARÃO BOAS COLHEITAS,\nA CRIAÇÃO LHE APRAZ, O SOL DIRIGE A\nLUA, ESCONDE A NOITE EM DIA FAZ.'}]},
#    {'slide': '90',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 6120778,
#       'top': 415495,
#       'text': 'GRANDE É O SENHOR,\nO SOBERANO LÁ NOS CÉUS,\nE REI DOS REIS ONIPOTENTE E SANTO \nDEUS, GRANDE EM SEU PODER,\nE MASJESTOSO EM SEU SABER.\nSUA BONDADE É IMENSURAVÉL COMO \nO MAR, SEU AMPLO AMOR É \nINDISPENSÁVEL COMO O AR, \nSANTO É O SENHOR, \nVINDE ADORÁ-LO COM LOUVOR.'}]},
#    {'slide': '91',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 5277086,
#       'top': 927199,
#       'text': 'HOSANA AO SALVADOR, \n(UNIDOS TODOS NÓS) VARÕES\nCANTEMOS EM LOUVOR,\n(CANTEMOS NUMA VOZ) VARÕES\nHOSANA AO NOSSO DEUS,\nHOSANA AO SALVADOR,\nHOSANA AO SENHOR,\nHOSANA AO SENHOR, AO SENHOR.'},
#      {'text': 'Índice'}]}]},
#  {'slides': [{'slide': '92',
#     'shapes': [{'text': 'HOJE EU DESCOBRI A FORMA DE VIVER FELIZ, \nA CRISTO EU ENTREGUEI A MINHA VIDA E ESPEREI,\nA SOLUÇÃO DOS MEUS PROBLEMAS.\nE A RESPOSTA EM CRISTO EU ACHEI.'},
#      {'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 586581,
#       'top': 423143,
#       'text': 'HOJE EU DESCOBRI'}]},
#    {'slide': '93',
#     'shapes': [{'text': 'HOJE EU VIVO BEM E A SUA PAZ EU ENCONTREI, \nO FARDO TÃO PESADO \nNO CAMINHO EU DEIXEI.\nELE O TOMOU EM SUA CRUZ E DISSE-ME: \n“FILHO MEU, TE ALIVIAREI”.'}]},
#    {'slide': '94',
#     'shapes': [{'text': 'CORO\nFICA SENHOR, EM MEU CORAÇÃO,\nMORA SENHOR, EM MEU CORAÇÃO.\n\nINSTRUMENTOS'}]},
#    {'slide': '95',
#     'shapes': [{'text': 'HOJE EU VIVO BEM E A SUA PAZ EU ENCONTREI, \nO FARDO TÃO PESADO \nNO CAMINHO EU DEIXEI.\nELE O TOMOU EM SUA CRUZ E DISSE-ME: \n“FILHO MEU, TE ALIVIAREI”.'}]},
#    {'slide': '96',
#     'shapes': [{'text': 'CORO\nFICA SENHOR, EM MEU CORAÇÃO,\nMORA SENHOR, EM MEU CORAÇÃO.'},
#      {'text': 'Índice'}]}]},
#  {'slides': [{'slide': '97',
#     'shapes': [{'text': 'JERUSALÉM, EM TUAS RUAS \nEU OUÇO A ECOAR\nO SOM DA HARPA DE DAVI,\nMINHA ALMA A ACALENTAR\nPOR ENTRE AS TUAS OLIVEIRAS, \nO VENTO VEM CONTAR\nHISTÓRIAS DA VELHA CIDADE \nQUE OS MUROS VÃO GUARDAR.'},
#      {'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 586581,
#       'top': 351135,
#       'text': 'JERUSALÉM DE OURO'}]},
#    {'slide': '98',
#     'shapes': [{'text': 'CORO\nJERUSALÉM, JERUSALÉM,\nBELEZA E COR DE ISRAEL,\nTU ÉS O ORGULHO DO TEU DEUS,\nEMANUEL.'},
#      {'text': ''},
#      {'auto_shape': 'ROUNDED_RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 556179,
#       'top': 3548117,
#       'text': 'BIS'}]},
#    {'slide': '99',
#     'shapes': [{'text': 'AINDA OUÇO EM TUAS RUAS \nO SOM DA MULTIDÃO,\nDE PEREGRINOS E AMANTES \nEM BUSCA DE OBLAÇÃO,\nNO SANTO TEMPLO E EM TUAS FONTES\nSE ENCONTRAVA A PAZ,\nJERUSALÉM, QUEM TE CONHECE \nNÃO TE ESQUECE MAIS.'}]},
#    {'slide': '100',
#     'shapes': [{'text': 'CORO\nJERUSALÉM, JERUSALÉM,\nBELEZA E COR DE ISRAEL,\nTU ÉS O ORGULHO DO TEU DEUS,\nEMANUEL.'},
#      {'text': ''},
#      {'auto_shape': 'ROUNDED_RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 556179,
#       'top': 3548117,
#       'text': 'BIS'}]},
#    {'slide': '101',
#     'shapes': [{'text': 'JERUSALÉM, EM TUAS PRECES \nLEMBRA DOS FILHOS TEUS\nQUE AINDA NÃO TE CONHECERAM \nMAS AMAM O TEU DEUS,\nSÃO VELHOS, JOVENS E MENINOS \nDISTANTES DO SEU LAR,\nQUE NÃO PISARAM TUAS RUAS \nMAS VIVEM POR TE AMAR.'}]},
#    {'slide': '102',
#     'shapes': [{'text': 'CORO\nJERUSALÉM, JERUSALÉM,\nBELEZA E COR DE ISRAEL,\nTU ÉS O ORGULHO DO TEU DEUS,\nEMANUEL.'},
#      {'text': ''},
#      {'auto_shape': 'ROUNDED_RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 556179,
#       'top': 3548117,
#       'text': 'BIS'},
#      {'text': 'Índice'}]}]},
#  {'slides': [{'slide': '103',
#     'shapes': [{'text': 'JESUS, SEMPRE TE AMO \nPORQUE SEI QUE ÉS MEU;\nFELIZ EU TE RENDO LOUVOR \nQUE É SÓ TEU.\n\nMEU MESTRE DIVINO, \nSENHOR E MEU DEUS, \nPRA SEMPRE HEI DE AMAR-TE \nMEU CRISTO, MEU REI.'},
#      {'auto_shape': 'RIGHT_BRACE',
#       'shape': 'AUTO_SHAPE',
#       'height': 2455494,
#       'top': 1376149,
#       'text': ''},
#      {'text': 'SERVAS'},
#      {'auto_shape': 'RIGHT_BRACE',
#       'shape': 'AUTO_SHAPE',
#       'height': 2453865,
#       'top': 4305982,
#       'text': ''},
#      {'text': 'VARÕES'},
#      {'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 586581,
#       'top': 351135,
#       'text': 'JESUS, SEMPRE TE AMO'}]},
#    {'slide': '104',
#     'shapes': [{'text': 'EU TE AMO PORQUE TU MORRESTE POR MIM; \nEU TE AMO PORQUE TEU AMOR NÃO TEM FIM.\nEM TI CONFIANÇA PRA SEMPRE TEREI; \nPRA SEMPRE HEI DE AMAR-TE MEU REI.'}]},
#    {'slide': '105',
#     'shapes': [{'text': 'EU TE AMO NA VIDA, NA MORTE TAMBÉM;\nSEMPRE HEI DE LOUVAR-TE NA GLÓRIA DE ALÉM;\nAGORA E PRA SEMPRE POR TI VIVEREI;\nSEMPRE HEI DE AMAR-TE, \nMEU CRISTO, MEU REI.\nSEMPRE HEI DE AMAR-TE, \nMEU CRISTO, MEU REI.'},
#      {'text': 'Índice'}]}]},
#  {'slides': [{'slide': '106',
#     'shapes': [{'auto_shape': 'ROUNDED_RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 3115213,
#       'top': 2079327,
#       'text': 'JESUS, SOMENTE TU, \nA MINHA SEDE PODE SACIAR,\nNADA TEM MAIS VALOR, \nDO QUE BUSCAR TUA FACE E TE ADORAR.'},
#      {'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 586581,
#       'top': 412626,
#       'text': 'JESUS, SOMENTE TU'}]},
#    {'slide': '107',
#     'shapes': [{'text': 'CORO\nSÓ TU ÉS A LUZ DA MINHA VIDA,\nSÓ TU DÁS SENTIDO AO MEU VIVER,\nSÓ TU VÊS A MINHA ALMA FERIDA,\nSÓ TU TENS PODER PRA EU VENCER.'}]},
#    {'slide': '108',
#     'shapes': [{'text': 'JESUS, EU TE AMO,\nVEM MINHA SEDE AGORA SACIAR;\nENCHE MINH’ALMA COM TEU AMOR \nATÉ EU TRANSBORDAR.'}]},
#    {'slide': '109',
#     'shapes': [{'text': 'CORO\nSÓ TU ÉS A LUZ DA MINHA VIDA,\nSÓ TU DÁS SENTIDO AO MEU VIVER,\nSÓ TU VÊS A MINHA ALMA FERIDA,\nSÓ TU TENS PODER PRA EU VENCER.'},
#      {'text': ''},
#      {'auto_shape': 'ROUNDED_RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 537712,
#       'top': 3287586,
#       'text': 'BIS'},
#      {'text': 'Índice'}]}]},
#  {'slides': [{'slide': '110',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 586581,
#       'top': 412626,
#       'text': 'JUNTO A TI'},
#      {'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 2746008,
#       'top': 2146484,
#       'text': 'JUNTO A TI, QUERO ESTAR, \nEM TUA CASA HABITAR, \nTEU AMOR EM MIM SENTIR,\nTUA VOZ SUAVE OUVIR, JESUS!'}]},
#    {'slide': '111',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 3426194,
#       'top': 1867426,
#       'text': 'CORO\nTU ÉS TUDO QUE EU \nALMEJO MINHA VIDA E LUZ, \nCADA DIA TE DESEJO MAIS \nE MAIS, JESUS.'}]},
#    {'slide': '112',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 2844112,
#       'top': 2122382,
#       'text': 'PELO ALTAR JÁ PASSEI\nE NO SANGUE ME LAVEI,\nPOSSO AGORA TE ADORAR\nMINHA SEDE SACIAR, JESUS!'}]},
#    {'slide': '113',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 4744889,
#       'top': 1376150,
#       'text': 'CORO (2X)\nTU ÉS TUDO QUE EU \nALMEJO MINHA VIDA E LUZ, \nCADA DIA TE DESEJO MAIS \nE MAIS, JESUS.\n\nINSTRUMENTOS'}]},
#    {'slide': '114',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 3426194,
#       'top': 1867426,
#       'text': 'CORO\nTU ÉS TUDO QUE EU \nALMEJO MINHA VIDA E LUZ, \nCADA DIA TE DESEJO MAIS \nE MAIS, JESUS.'},
#      {'text': 'Índice'}]}]},
#  {'slides': [{'slide': '115',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 2746008,
#       'top': 2079327,
#       'text': 'LOUVAI A DEUS, SENHOR, VINDE ADORÁ-LO,\nEM SEUS ATRIOS ENTOAI HINOS DE LOUVOR.\nLOUVAI A DEUS, SENHOR, VINDE ADORÁ-LO,\nEM SEUS ATRIOS ENTOAI HINOS DE LOUVOR.'},
#      {'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 586581,
#       'top': 412626,
#       'text': 'LOUVAI A DEUS, SENHOR'}]},
#    {'slide': '116',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 4359527,
#       'top': 1071215,
#       'text': 'CÉUS ALEGRAI-VOS, TERRA EXULTAI,\nPERANTE A FACE DO SENHOR QUE VEM, ALELUIA.\nCÉUS ALEGRAI-VOS, TERRA EXULTAI,\nPERANTE A FACE DO SENHOR QUE VEM, ALELUIA.\n\nALELUIA, ALELUIA, ALELUIA, ALELUIA, ALELUIA, \nALELUIA, ALELUIA, ALELUIA, ALELUIA, ALELUIA.'}]},
#    {'slide': '117',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 4359527,
#       'top': 1014502,
#       'text': 'ANJOS CANTAI, Ó NAÇÕES EXULTAI,\nPERANTE A FACE DO SENHOR QUE VEM, ALELUIA.\nANJOS CANTAI, Ó NAÇÕES EXULTAI,\nPERANTE A FACE DO SENHOR QUE VEM, ALELUIA.\n\nALELUIA, ALELUIA, ALELUIA, ALELUIA, ALELUIA, \nALELUIA, ALELUIA, ALELUIA, ALELUIA, ALELUIA.'}]},
#    {'slide': '118',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 2746008,
#       'top': 2336957,
#       'text': 'ANJOS CANTAI, Ó NAÇÕES EXULTAI,\nPERANTE A FACE DO SENHOR QUE VEM, ALELUIA.\nANJOS CANTAI, Ó NAÇÕES EXULTAI,\nPERANTE A FACE DO SENHOR QUE VEM, ALELUIA.'},
#      {'text': 'Índice'}]}]},
#  {'slides': [{'slide': '119',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 5615255,
#       'top': 1288608,
#       'text': 'ALELUIA (ALELUIA), ALELUIA (ALELUIA)\nALELUIA, ALELUIA, ALELUIA, ALELUIA.\n\nLOUVAI AO SENHOR NO SEU SANTUÁRIO,\nLOUVAI AO SENHOR NO FIRMAMENTO \nDO SEU PODER, LOUVAI AO NOSSO DEUS, \nPOR SEUS FEITOS PODEROSOS,\nLOUVAI-O CONFORME A SUA \nGRANDEZA.'},
#      {'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 586581,
#       'top': 412626,
#       'text': 'LOUVAI AO SENHOR (SALMO 150)'}]},
#    {'slide': '120',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 4572630,
#       'top': 1365990,
#       'text': 'Ó LOUVAI AO SENHOR AO TOCAR DA TROMBETA,\nÓ LOUVAI AO SENHOR COM SALTÉRIO E COM HARPA,\nLOUVAI COM ADUFE, COM JÚBILO LOUVAI,\nLOUVAI-O COM ÓRGÃOS E CORDAS LOUVAI,\nLOUVAI AO SENHOR COM CÍMBALOS SONOROS,\nLOUVAI AO SENHOR COM CÍMBALOS RETUMBANTES,\nE TODO O SER QUE RESPIRA, E TODO O SER QUE \nRESPIRA LOUVE AO SENHOR, \nSIM LOUVE AO SENHOR.'}]},
#    {'slide': '121',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 2746008,
#       'top': 2223343,
#       'text': 'LOUVAI AO SENHOR NO SEU SANTUÁRIO,\nLOUVAI AO SENHOR NO FIRMAMENTO DO SEU PODER,\nLOUVAI AO NOSSO DEUS, POR SEUS FEITOS PODEROSOS,\nLOUVAI-O CONFORME A SUA GRANDEZA.'}]},
#    {'slide': '122',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 2746008,
#       'top': 2353643,
#       'text': 'Ó LOUVAI AO SENHOR AO TOCAR DA TROMBETA,\nO LOUVAI AO SENHOR COM SALTÉRIO E COM HARPA,\nLOUVAI COM ADUFE, COM JÚBILO LOUVAI,\nALELUIA, ALELUIA, ALELUIA, ALELUIA.'},
#      {'text': 'Índice'}]}]},
#  {'slides': [{'slide': '123',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 5495024,
#       'top': 1359247,
#       'text': 'MAIS PUREZA DÁ-ME,                       \nREJEIÇÃO AO MAL,                            \nMAIS CALMA NAS LUTAS,                       \nMAIS ALTO IDEAL;                              \nMAIS FÉ NO MEU MESTRE,                      \nMAIS CONSAGRAÇÃO,                       \nMAIS GOZO EM SERVI-LO,                   \nMAIS GRATA ORAÇÃO.'},
#      {'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 586581,
#       'top': 351135,
#       'text': 'MAIS PUREZA DÁ-ME'}]},
#    {'slide': '124',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 6216386,
#       'top': 567159,
#       'text': 'MAIS PRUDENTE FAZE-ME,                  \nMAIS SÁBIO, SENHOR;                        \nMAIS FIRME EM CRISTO,                      \nMAIS FORÇAS NA DOR;                      \nMAIS RETO NA VIDA,                          \nMAIS TRISTE AO PECAR;                      \nMAIS HUMILDE FILHO,                        \nMAIS PRONTO EM AMAR.'}]},
#    {'slide': '125',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 5952780,
#       'top': 523036,
#       'text': 'MAIS PURO FAZE-ME,                             \nMAIS SANTO EM JESUS;                           \nMAIS DO TEU DOMÍNIO,                            \nMAIS GOZO NA CRUZ.                          \nMAIS RICA ESPERANÇA,                       \nMAIS FÉ E PODER.                                \nMAIS ÂNSIA DO CÉU,                            \nMAIS VIDA EM TI.'},
#      {'text': 'Índice'}]}]},
#  {'slides': [{'slide': '126',
#     'shapes': [{'text': 'JESUS NOS PROMETEU UM\nCONSELHEIRO SER,\nO FORTE DEUS, PRÍNCIPE DA\nPAZ, E COMO UM PAI SERIA\nPARA DAR-NOS AMOR, TÃO\nGRANDE QUE NÃO CESSARÁ\nJAMAIS.'},
#      {'text': 'SERVAS'},
#      {'auto_shape': 'RIGHT_BRACE',
#       'shape': 'AUTO_SHAPE',
#       'height': 4742830,
#       'top': 1511261,
#       'text': ''},
#      {'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 586581,
#       'top': 412626,
#       'text': 'MAIS QUE MARAVILHOSO'}]},
#    {'slide': '127',
#     'shapes': [{'text': 'DESCOBRI QUE JESUS CRISTO\nÉ UM DEUS FIEL.\nO QUE NOS PROMETEU\nCUMPRIU ENFIM.\nENTÃO, A MEU JESUS DESEJO\nCONFESSAR O QUE ELE\nREPRESENTA PARA MIM.'},
#      {'text': 'VARÕES'},
#      {'auto_shape': 'RIGHT_BRACE',
#       'shape': 'AUTO_SHAPE',
#       'height': 4764343,
#       'top': 1143223,
#       'text': ''}]},
#    {'slide': '128',
#     'shapes': [{'text': 'CORO\nMARAVILHOSO DEUS,\nMUITO MAIS QUE MEU SER \nPOSSA IMAGINAR, MUITO MAIS DO QUE SEI.\nPOIS ELE É MAIS, BEM MUITO MAIS DO QUE SONHEI.\nNELE ENCONTREI TUDO QUE PROCURAVA\nO QUE PRECISAVA SÓ NELE ACHEI:\nMARAVILHOSO, MUITO MAIS PRA MIM;\nDEUS MILAGROSO É, SEMPRE SERÁ\nMARAVILHOSO DEUS,\nÉ O QUE CRISTO É PRA MIM.'}]},
#    {'slide': '129',
#     'shapes': [{'text': 'AO RELEMBRAR QUE UM DIA,\nO REI DA GLÓRIA EM FORMA\nDE UM HOMEM SE TORNOU,\nFELIZ ME FAZ POIS SEI\nQUANTO ME AMAS, AO\nPENSAR QUEM ELE É\nE QUEM EU SOU.'},
#      {'text': 'VARÕES'},
#      {'auto_shape': 'RIGHT_BRACE',
#       'shape': 'AUTO_SHAPE',
#       'height': 4619327,
#       'top': 1251626,
#       'text': ''}]},
#    {'slide': '130',
#     'shapes': [{'text': 'CORO\nMARAVILHOSO DEUS,\nMUITO MAIS QUE MEU SER POSSA\nIMAGINAR, MUITO MAIS DO QUE SEI.\nPOIS ELE É MAIS, BEM MUITO MAIS DO QUE SONHEI.\nNELE ENCONTREI TUDO QUE PROCURAVA \nO QUE PRECISAVA SÓ NELE ACHEI:\nMARAVILHOSO, MUITO MAIS PRA MIM;\nDEUS MILAGROSO É, SEMPRE SERÁ \nMARAVILHOSO DEUS,\nÉ O QUE CRISTO É PRA MIM.'}]},
#    {'slide': '131',
#     'shapes': [{'text': 'FINAL:\nNELE ENCONTREI TUDO QUE\nPROCURAVA, O QUE PRECISAVA SÓ\nNELE ACHEI: MARAVILOSO, MUITO MAIS, PRA MIM;\nDEUS MILAGROSO É, SEMPRE SERÁ\nMARAVILHOSO DEUS,\nPODEROSO DEUS É, SEMPRE SERÁ\nMARAVILHOSO DEUS, PODEROSO DEUS, \nÉ O QUE CRISTO É PRA MIM.\nMARAVILHOSO É PRA MIM, PRA MIM.'},
#      {'text': 'Índice'}]}]},
#  {'slides': [{'slide': '132',
#     'shapes': [{'text': 'SENHOR JESUS EXALTADO SEJA\nSEMPRE O TEU SANTO NOME.\nNOME SANTO E BOM. (ÉS TU SENHOR)\nNOME SANTO E BOM. (É SALVADOR)\nEXALTADO SEJA SEMPRE \nO NOME DE JESUS.'},
#      {'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 586581,
#       'top': 489251,
#       'text': 'MIL GLÓRIAS'}]},
#    {'slide': '133',
#     'shapes': [{'text': 'EXALTADO SEJA SEMPRE \nO TEU NOME, Ó JESUS.\nTU QUE HABITAS LÁ NA GLÓRIA,\nÓ AMADO JESUS.\n\nGLÓRIA A JESUS, GLÓRIA A JESUS\nJESUS CRISTO ESTÁ NA GLÓRIA\nREVESTIDO DE PODER.'},
#      {'text': 'BIS'},
#      {'auto_shape': 'RIGHT_BRACE',
#       'shape': 'AUTO_SHAPE',
#       'height': 2771596,
#       'top': 682035,
#       'text': ''},
#      {'text': 'BIS'},
#      {'auto_shape': 'RIGHT_BRACE',
#       'shape': 'AUTO_SHAPE',
#       'height': 2032514,
#       'top': 4367293,
#       'text': ''}]},
#    {'slide': '134',
#     'shapes': [{'text': 'GLÓRIA A JESUS CRISTO, ELE É O SALVADOR.\nFOI QUEM POR NÓS COM PODE NOS RESGAROU.\nGLÓRIA AO PAI CELESTE, \nGLÓRIA A JESUS CRISTO, O FILHO,\nQUE SALVOU AS NOSSAS ALMAS,\nCOM PODER NOS RESGATOU.\nELE ESTÁ SENTADO, REVESTIDO \nDE PODER ESPERANDO PELO PAI \nPRA USA IGREJA RECEBER.'}]},
#    {'slide': '135',
#     'shapes': [{'text': 'E ESTA JORNADA VAMOS ENCERRAR.\nE NOSSA COROA LÁ NO CÉU VAMOS GANHAR.\nTE PREPARA, Ó CRENTE PRA ENCONTRAR O SALVADOR,\nPOIS EM BREVE ESTA IGREJA VAI SUBIR COM O SENHOR.\nELE VEM NAS NUVENS COM PODER E \nGRANDE GLÓRIA PRA BUSCAR A IGREJA\nSANTA QUE RECEBEU A VITÓRIA.'}]},
#    {'slide': '136',
#     'shapes': [{'text': 'GLÓRIA, GLÓRIA, JESUS,\nCRISTO ESTÁ NA GLÓRIA \nREVESTIDO DE PODER\n\nAO SENHOR DAÍ GLÓRIA,\nDAÍ GLÓRIA.\nPRA SEMPRE, AMÉM.'},
#      {'text': 'BIS'},
#      {'auto_shape': 'RIGHT_BRACE',
#       'shape': 'AUTO_SHAPE',
#       'height': 2075846,
#       'top': 1080517,
#       'text': ''}]},
#    {'slide': '137',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 2478675,
#       'top': 2336956,
#       'text': 'ABENÇOA-NOS SENHOR,\nDERRAMA SOBRE NÓS TUA PAZ\nABENÇOA-NOS SENHOR,\nDERRAMA SOBRE NÓS TEU AMOR.'},
#      {'text': 'Índice'}]}]},
#  {'slides': [{'slide': '138',
#     'shapes': [{'text': 'NO EXÍLIO BEM DISTANTE,\nMINHA TERRA VOU CANTAR,\nÉ DE TODAS A MAIS BELA,\nCOM ELA VIVO A SONHAR,\nÉ MAIS SALUBRE O SEU CLIMA\nDO QUE DESTA SOLIDÃO.'},
#      {'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 586581,
#       'top': 412626,
#       'text': 'NO EXÍLIO'}]},
#    {'slide': '139',
#     'shapes': [{'text': 'CORO\nEU TENHO SAUDADES DELA\nOH! QUANDO IREI PRA SIÃO?\nOH! BELA SIÃO, MINHA TERRA É SIÃO;\nEU TENHO SAUDADES DELA,\nOH! QUANDO IREI PRA SIÃO?'}]},
#    {'slide': '140',
#     'shapes': [{'text': 'LÁ NÃO HÁ CHORO E NEM GUERRA,\nE NEM MESMO REVOLUÇÃO,\nPASTA O LOBO COM O CORDEIRO\nE O NOVILHO COM O LEÃO,\nE O MENINO APASCENTA\nCOM O CAJADO NA MÃO.'}]},
#    {'slide': '141',
#     'shapes': [{'text': 'CORO\nEU TENHO SAUDADES DELA\nOH! QUANDO IREI PRA SIÃO?\nOH! BELA SIÃO, MINHA TERRA É SIÃO;\nEU TENHO SAUDADES DELA,\nOH! QUANDO IREI PRA SIÃO?'}]},
#    {'slide': '142',
#     'shapes': [{'text': 'CORO\nOH! BELA SIÃO, MINHA TERRA É SIÃO;\nEU TENHO SAUDADES DELA,\nOH! QUANDO IREI PRA SIÃO?\n\nFINAL: \nOH! QUANDO IREI PRA SIÃO?'},
#      {'text': 'Índice'}]}]},
#  {'slides': [{'slide': '143',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 3053400,
#       'top': 2041323,
#       'text': 'DEUS MESMO REVELOU O NOVO CÉU;\nDEUS MESMO REVELOU O NOVO CÉU\nE A NOVA TERRA,\nESTA TERRA NÃO MAIS EXISTIRÁ;\nESTA TERRA NÃO MAIS EXISTIRÁ,'},
#      {'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 586581,
#       'top': 412626,
#       'text': 'O NOVO CÉU'}]},
#    {'slide': '144',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 2549801,
#       'top': 2336957,
#       'text': 'NOVO É ESTE CÉU E O MAR TAMBÉM SE DESFEZ,\nO EVANGELISTA VIU A CIDADE DO SENHOR,\nCIDADE DO SENHOR, CIDADE DO SENHOR,\nQUE APRESENTAVA A GLÓRIA DO SENHOR.'}]},
#    {'slide': '145',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 3177665,
#       'top': 1808627,
#       'text': 'NO BRILHO DE DEUS E NOSSO ETERNO PAI;\nNO BRILHO DE DEUS E NOSSO ETERNO PAI;\nNO BRILHO DE NOSSO ETERNO \nPAI E REDENTOR DOS CÉUS,\nNOSSO PAI DOS CÉUS.'}]},
#    {'slide': '146',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 5061257,
#       'top': 1050518,
#       'text': 'E SOOU UMA VOZ MUI FORTE, \nDIZENDO: EIS DE DEUS A HABITAÇÃO \nENTRE OS HOMENS COM OS SEUS SERVOS,\nPOIS DEUS VAI HABITAR, VAI MORAR COM OS SEUS.\nENTÃO VEREIS, ENTÃO VEREIS, ENTÃO VEREIS, \nENTÃO VEREIS A GLÓRIA DIVINA,\nE DEUS VOS GUIARÁ E SERÁ \nO VOSSO PAI.'}]},
#    {'slide': '147',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 6650539,
#       'top': 351135,
#       'text': 'TODA LÁGRIMA ELE LIMPARÁ;\nTODA LÁGRIMA ELE LIMPARÁ;\nTODA LÁGRIMA ELE LIMPARÁ;\nTODA LÁGRIMA ELE LIMPARÁ.\n\nSIM, DOS VOSSOS OLHOS TODA \nA LÁGRIMA LIMPARÁ, LIMPARÁ, \nLIMPARÁ, LIMPARÁ.\n\nLOUVAI A DEUS, LOUVAI A DEUS, \nLOUVAI A DEUS, LOUVAI A DEUS, \nALELUIA.'},
#      {'text': ''},
#      {'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 551305,
#       'top': 1189985,
#       'text': 'BIS'},
#      {'text': 'Índice'}]}]},
#  {'slides': [{'slide': '148',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 4632718,
#       'top': 1399650,
#       'text': 'QUANDO PARO PRA PENSAR\nEM TEU GRANDE AMOR\nPENSO: “PODE DEUS AMAR A MIM PECADOR?”\nAO SENTIR O TEU PODER MANIFESTO EM MIM, \nEU NÃO CONSIGO COMPREENDER\nPORQUE ME AMAS TANTO ASSIM.'},
#      {'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 586581,
#       'top': 415343,
#       'text': 'O SENHOR É MINHA ROCHA'}]},
#    {'slide': '149',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 6361148,
#       'top': 470707,
#       'text': 'POIS O SENHOR É MINHA ROCHA\nMEU REFÚGIO É O SENHOR.\nNÃO TEMEREI, MAS FORTE SEREI\nQUANDO O MAL SOBRE MIM VIER\nPOIS O SENHOR É MINHA FORTALEZA \nE MEU PROTETOR SE EM PROVAÇÃO, \nME AJUDAS GRANDE É O AMOR \nQUE TENS POR MIM.'}]},
#    {'slide': '150',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 6115109,
#       'top': 644738,
#       'text': 'QUANDO OLHO PARA OS CÉUS, \nOBRA DE TUAS MÃOS,\nVEJO O QUANTO ÉS GRANDE, \nÓ DEUS POR TUA CRIAÇÃO\nÓ MEU PAI, SENHOR DA LUZ, \nSOU UM PECADOR MAS SEI QUE \nO SANGUE DE JESUS \nFAZ DE MIM UM VENCEDOR!'}]},
#    {'slide': '151',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 6326931,
#       'top': 432916,
#       'text': 'POIS O SENHOR É MINHA ROCHA\nMEU REFÚGIO É O SENHOR.\nNÃO TEMEREI, MAS FORTE SEREI\nQUANDO O MAL SOBRE MIM VIER\nPOIS O SENHOR É MINHA FORTALEZA \nE MEU PROTETOR, SE EM PROVAÇÃO ME\nAJUDAS, GRANDE É O AMOR QUE \nTENS POR MIM.'}]},
#    {'slide': '152',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 4640362,
#       'top': 1111373,
#       'text': 'POR ISSO PEÇO, Ó PAI, \nCOMIGO SÊ NESTA LUTA AQUI.\nLOUVOR, ENTÃO, HEI DE RENDER\nEM GRATIDÃO A TI. \nA TI, Ó PAI DE AMOR!\nPAI DE AMOR!'}]},
#    {'slide': '153',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 6282198,
#       'top': 415343,
#       'text': 'POIS O SENHOR É MINHA ROCHA.\nMEU REFÚGIO É O SENHOR\nNÃO TEMEREI, MAS FORTE SEREI\nQUANDO O MAL SOBRE MIM VIER\nPOIS O SENHOR É MINHA FORTALEZA \nE MEU PROTETOR SE EM PROVAÇÃO \nME AJUDAS GRANDE É O AMOR \nQUE TENS POR MIM!\nFINAL: SENHOR, TU ÉS A MINHA ROCHA.'},
#      {'text': 'Índice'}]}]},
#  {'slides': [{'slide': '154',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 5457604,
#       'top': 1302243,
#       'text': 'POR NOSSA PÁTRIA ORAMOS A TI, \nÓ SUPREMO DEUS!\nPOR NOSSO LAR CLAMAMOS A TI, \nÓ REI DO CÉUS.\nGOVERNA A PÁTRIA COM AMOR,\nSÊ NOSSO AMPARO, Ó SALVADOR. \nDERRAMA GRAÇA COM FAVOR,\nDEUS SALVE A PÁTRIA!'},
#      {'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 586581,
#       'top': 415343,
#       'text': 'ORAÇÃO PELA PÁTRIA'}]},
#    {'slide': '155',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 5326483,
#       'top': 832622,
#       'text': 'À PÁTRIA QUE NOS DESTE,\nESTENDE TUA MÃO.\nCOM BÊNÇÃOS NOS REVESTE,\nDÁ-NOS PAZ,CONSOLAÇÃO.\nSUSTENTA A ORDEM NACIONAL, \nO BOM GOVERNO IMPARCIAL; \nE DÁ-NOS GRAÇA DIVINAL,\nDEUS SALVE A PÁTRIA!'}]},
#    {'slide': '156',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 5337889,
#       'top': 858792,
# ...
#       'height': 2376264,
#       'top': 2192913,
#       'text': ''},
#      {'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 587211,
#       'top': 3087439,
#       'text': 'BIS'}]}]},
#  {'slides': [{'slide': '369',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 4358565,
#       'top': 1507355,
#       'text': 'A TROMBETA ESTÁ PRA SOAR,\nANUNCIANDO QUE CRISTO VOLTARÁ.\nALERTA IGREJA AMADA, TUDO JÁ SE CUMPRIU.\n\nOS ANJOS JÁ ESTÃO PREPARADOS,\nESPERANDO O MOMENTO DE SOAR A TROMBETA, \nPORQUE O SENHOR JÁ VEM!'},
#      {'text': 'O FIM VEM!'}]},
#    {'slide': '370',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 4024628,
#       'top': 1310028,
#       'text': 'CORO  \nIGREJA O FIM VEM! O FIM VEM!\nJESUS, SIM VEM! JESUS VEM! \nÉ O MOMENTO DE PREPARADOS JÁ ESTARMOS \nPORQUE O FIM VEM!'}]},
#    {'slide': '371',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 738664,
#       'top': 332551,
#       'text': 'Na estrada da vida (jesus companheiro)'},
#      {'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 3138423,
#       'top': 1896313,
#       'text': 'NA ESTRADA DA VIDA DE ESTRANHOS MISTÉRIOS\nFIEL COMPANHEIRO É CRISTO, O SENHOR\nPRESENTE CONSTANTE AO LONGO DA ESTRADA\nJESUS COMPANHEIRO ME ANIMA COM AMOR.'}]},
#    {'slide': '372',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 3138423,
#       'top': 1896313,
#       'text': 'NÃO ESTOU SOZINHO, EU TENHO UM AMIGO,\nEM MEIO AOS PERIGOS PRESENTE ELE ESTÁ!\nNÃO ME DESAMPARA EM MEIO À JORNADA\nJESUS COMPANHEIRO COMIGO ESTARÁ.'}]},
#    {'slide': '373',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 3138423,
#       'top': 1896313,
#       'text': 'O BOM COMANHEIRO É AQUELE QUE AJUDA\nNA ETERNA CONQUISTA DA VIDA REAL.\nJESUS É ESTE AMIGO DE DOCE BONDADE\nQUE DEU À MINHA ALMA O GOZO ETERNAL.'},
#      {'text': 'Índice'}]}]},
#  {'slides': [{'slide': '374',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 738664,
#       'top': 332551,
#       'text': 'PÕE-ME COMO SELO'},
#      {'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 3138423,
#       'top': 1749216,
#       'text': 'CORO \nPÕE-ME COMO SELO SOBRE O TEU CORAÇÃO COMO SELO SOBRE O TEU BRAÇO, O AMOR É FORTE COMO A MORTE, SUAS BRASAS SÃO BRASAS DE FOGO,'}]},
#    {'slide': '375',
#     'shapes': [{'text': 'AS MUITAS ÁGUAS NÃO PODEM APAGAR ESTE AMOR NEM OS RIOS AFOGÁ-LO, \nAS MUITAS ÁGUAS NÃO PODEM APAGAR ESTE AMOR NEM OS RIOS AFOGA-LO!'}]},
#    {'slide': '376',
#     'shapes': [{'text': 'Ó TU QUE HABITA OS JARDINS, \nOS COMPANHEIROS ATENTOS \nPARA OUVIR A TUA VOZ \nFAZ-ME TAMBÉM OUVI-LA.'}]},
#    {'slide': '377',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 3138423,
#       'top': 1749216,
#       'text': 'CORO \nPÕE-ME COMO SELO SOBRE O TEU CORAÇÃO COMO SELO SOBRE O TEU BRAÇO, O AMOR É FORTE COMO A MORTE, SUAS BRASAS SÃO BRASAS DE FOGO,'}]},
#    {'slide': '378',
#     'shapes': [{'text': 'Ó TU QUE HABITA OS JARDINS, \nOS COMPANHEIROS ATENTOS \nPARA OUVIR A TUA VOZ \nFAZ-ME TAMBÉM OUVI-LA. \n\nFINAL: COMO O AMOR, \n           COMO O AMOR...'},
#      {'text': 'Índice'}]}]},
#  {'slides': [{'slide': '379',
#     'shapes': [{'text': 'EIS-ME, Ó SALVADOR, AQUI! \nCORPO E ALMA OFERTO A TI!\nSERVO INÚTIL SEM VALOR, \nMAS PERTENÇO A MEU SENHOR!'},
#      {'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 586581,
#       'top': 412626,
#       'text': 'EIS-ME, Ó SALVADOR, AQUI'}]},
#    {'slide': '380',
#     'shapes': [{'text': 'FRACO EM OBRA E NO PENSAR; MUI PROPENSO A TROPEÇAR;\nSALVO ESTOU POR TEU AMOR \nE ME VOTO A TI, SENHOR!'}]},
#    {'slide': '381',
#     'shapes': [{'text': 'SUBJUGADO EM TODO O SER, \nME SUBMETO AO TEU PODER!\nGRANDE É O PREÇO DO PERDÃO, INTEIRA A CONSAGRAÇÃO!'}]},
#    {'slide': '382',
#     'shapes': [{'text': 'EU REMIDO PECADOR, \nME DEDICO AO REDENTOR.\nTEU É ESTE CORAÇÃO, \nTEU, EM PLENA SUJEIÇÃO!'}]},
#    {'slide': '383',
#     'shapes': [{'text': 'TOMA-ME, SENHOR JESUS! FAZ-ME ANDAR CONTIGO EM LUZ,\nSEM RESERVA, SEM TEMOR, \nTEU CATIVO, Ó SALVADOR.'},
#      {'text': 'Índice'}]}]},
#  {'slides': [{'slide': '384',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 893578,
#       'top': 207119,
#       'text': 'HONRA E GLÓRIA AO CORDEIRO'},
#      {'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 3293209,
#       'top': 1935311,
#       'text': 'JESUS NO CÉU ME ENCONTRARÁ \nQUANDO EU A VIDA AQUI FINDAR,\nE OS REDIMIDOS DO SENHOR\nLIBERTOS DO VIL TENTADOR. (VARÕES)\nAO CHEGAR À GLÓRIA, CANTAREI VITÓRIAS;'}]},
#    {'slide': '385',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 4573560,
#       'top': 1359247,
#       'text': 'CANTAREI (CANTAREI) \nQUE SANTO É DEUS (QUE SANTO É DEUS)\nSANTO E SANTO (SANTO E SANTO) \nÉ DEUS SENHOR (SANTO É DEUS)\nGLÓRIA E HONRA (GLÓRIA E HONRA) \nAO GRANDE DEUS (GRANDE DEUS)\nAO QUE É E HÁ DE SER.'}]},
#    {'slide': '386',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 4573560,
#       'top': 1215231,
#       'text': 'SANTO, SANTO (SANTO É DEUS) \nÉ DEUS SENHOR (SIM DEUS SENHOR)\nALELUIA! (ALELUIA!) \nCANTAREI (CANTAREI) \nCOM OS ANJOS (COM OS ANJOS) \nLÁ NOS CÉUS (LÁ NOS CÉUS),\nGLÓRIA, HONRA AO NOSSO DEUS!'}]},
#    {'slide': '387',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 3293209,
#       'top': 1882462,
#       'text': 'OH QUE BELAS VOZES VEM DO TRONO DO SENHOR;\nGLÓRIA CANTAM AO CORDEIRO \nA QUEM É SEU SALVADOR (SEU SALVADOR).\nHARMONIA SANTA VEM-ME COMO AS ONDAS EMBALAR.'},
#      {'text': 'Índice'}]}]},
#  {'slides': [{'slide': '388',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 2589876,
#       'top': 2224550,
#       'text': 'AO CORDEIRO GLÓRIA E HONRA, \nSALVOS NÃO CESSEIS DE DAR.\nGLÓRIA, HONRA SEMPRE A DEUS ENTOAREI! \nAMÉM!'},
#      {'text': 'Índice'}]}]},
#  {'slides': [{'slide': '389',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 769441,
#       'top': 279127,
#       'text': 'Jardim de oração'},
#      {'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 3230051,
#       'top': 2439367,
#       'text': 'O JARDIM ONDE CRISTO ME ESPERA \nÉ LUGAR DE DELÍCIAS E PAZ.\nPOIS O BRILHO DE SUA PRESENÇA \nDÁ-ME VIDA REAL EFICAZ.'}]},
#    {'slide': '390',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 3293209,
#       'top': 1647279,
#       'text': 'CORO\nOH! QUE LINDO JARDIM, O JARDIM DE ORAÇÃO \nONDE AS FLORES EXALAM PODER.\nMEU JESUS PERTO ESTÁ E O PORTÃO ABRIRÁ DESTE LINDO JARDIM DE ORAÇÃO.'}]},
#    {'slide': '391',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 2653034,
#       'top': 2192971,
#       'text': 'NO JARDIM ONDE CRISTO ME ESPERA \nEU DISPONHO MEUS MALES E DOR.\nE POR BÊNÇÃOS DE DEUS CONFORTADO DOU LOUVORES AO MEU SALVADOR.'}]},
#    {'slide': '392',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 3293209,
#       'top': 1647279,
#       'text': 'CORO\nOH! QUE LINDO JARDIM, O JARDIM DE ORAÇÃO \nONDE AS FLORES EXALAM PODER.\nMEU JESUS PERTO ESTÁ E O PORTÃO ABRIRÁ DESTE LINDO JARDIM DE ORAÇÃO.'}]},
#    {'slide': '393',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 2653034,
#       'top': 2151335,
#       'text': 'NO JARDIM ONDE CRISTO ME ESPERA \nE QUER TAMBÉM TE ACOLHER MEU IRMÃO.\nVEM FRUIR A INCESSANTE BONDADE \nQUE EMANA DE SEU CORAÇÃO.'}]},
#    {'slide': '394',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 3293209,
#       'top': 1647279,
#       'text': 'CORO\nOH! QUE LINDO JARDIM, O JARDIM DE ORAÇÃO \nONDE AS FLORES EXALAM PODER.\nMEU JESUS PERTO ESTÁ E O PORTÃO ABRIRÁ DESTE LINDO JARDIM DE ORAÇÃO.'},
#      {'text': 'Índice'}]}]},
#  {'slides': [{'slide': '395',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 1107996,
#       'top': 0,
#       'text': 'Pelas maravilhas'},
#      {'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 3785652,
#       'top': 1863303,
#       'text': 'PELAS MARAVILHAS E PELOS LIVRAMENTOS, SENHOR, DAMOS GRAÇAS E LOUVOR!\nÉS O DEUS ETERNO, FIEL, EMANUEL, \nDEUS DE AMOR. \nGLÓRIA AO CRIADOR!'}]},
#    {'slide': '396',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 4524315,
#       'top': 783183,
#       'text': 'ÉS JUSTO E RETO, TUA MAJESTADE MANIFESTARÁS, MANIFESTARÁS!\nEM MEIO AOS TEUS SERVOS, \nFIÉIS E REMIDOS, \nTUA LUZ BRILHARÁ PRA SEMPRE, \nDEUS TRIÚNO, EXCELSO SENHOR!'},
#      {'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 743217,
#       'top': 5751735,
#       'text': 'REPETIR O LOUVOR'}]},
#    {'slide': '397',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 3697872,
#       'top': 1863303,
#       'text': 'PELAS MARAVILHAS E PELOS LIVRAMENTOS, SENHOR, DAMOS GRAÇAS E LOUVOR!\nÉS O DEUS ETERNO, FIEL, EMANUEL, \nDEUS DE AMOR. \nGLÓRIA AO CRIADOR!'}]},
#    {'slide': '398',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 4524315,
#       'top': 783183,
#       'text': 'ÉS JUSTO E RETO, TUA MAJESTADE MANIFESTARÁS, MANIFESTARÁS!\nEM MEIO AOS TEUS SERVOS, \nFIÉIS E REMIDOS, \nTUA LUZ BRILHARÁ PRA SEMPRE, \nDEUS TRIÚNO, EXCELSO SENHOR!'},
#      {'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 743217,
#       'top': 5535711,
#       'text': 'FINAL: EXCELSO SENHOR!'},
#      {'text': 'Índice'}]}]},
#  {'slides': [{'slide': '399',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 769441,
#       'top': 279127,
#       'text': 'Toda terra Exaltai'},
#      {'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 2132892,
#       'top': 2439367,
#       'text': 'TODA TERRA EXALTAI NO SENHOR.\nVINDE, LHE RENDEI GLÓRIA \nE HONRA COM HINOS DE LOUVOR.'}]},
#    {'slide': '400',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 3493264,
#       'top': 1626662,
#       'text': 'SOLO MASCULINO\nE SABEI QUE O SENHOR, ELE É DEUS;\nPOIS FOI ELE QUE NOS FEZ O POVO SEU,\nO POVO SEU E OVELHAS DO SEU ETERNO, SEU ETERNO AMOR.'}]},
#    {'slide': '401',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 3493264,
#       'top': 1772856,
#       'text': 'PELAS ENTRADAS, VINDE ENTRAI A SUA GRAÇA CANTANDO COM LOUVOR.\nLOUVAI E BENDIZEI, \nLOUVAI E BENDIZEI AO BONDOSO DEUS, SENHOR'}]},
#    {'slide': '402',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 3493264,
#       'top': 1719287,
#       'text': 'MULHERES\nO SENHOR É BOM! A SUA VERDADE DURA,\nE A SUA FIDELIDADE DURA \nDE GERAÇÃO EM GERAÇÃO,\nDE GERAÇÃO EM GERAÇÃO.'}]},
#    {'slide': '403',
#     'shapes': [{'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 3426194,
#       'top': 1791295,
#       'text': 'GLÓRIA SEJA DADA AO PAI \nE AO FILHO E AO ESPÍRITO SANTO,\nCOMO FOI NO PRINCÍPIO \nE AGORA E PARA SEMPRE:\nAMÉM, AMÉM, AMÉM!'},
#      {'text': 'Índice'}]}]},
#  {'slides': [{'slide': '404',
#     'shapes': [{'text': 'EM OBEDIÊNCIA, SERVI AO SENHOR'},
#      {'text': 'EM OBEDIÊNCIA, SERVI AO SENHOR \nE EM HUMILDADE, BUSCAI AO SENHOR; \nDAS RIQUEZAS DO REINO DE DEUS, \nENCHEI O CORAÇÃO. \nE CHEIOS DO ESPÍRITO, \nNA BATALHA TEREIS VITÓRIA.'}]},
#    {'slide': '405',
#     'shapes': [{'text': 'CORO:\nO SENHOR SALVA, O SENHOR LIVRA, \nNÃO COM ESPADA, POIS DELE É A GUERRA; \nTOMA O CAJADO, DESCE AO RIBEIRO, \nDIANTE DA PELEJA O SENHOR É CONTIGO.'}]},
#    {'slide': '406',
#     'shapes': [{'text': 'PRUDENTEMENTE, ANDAI NO CAMINHO\nE TENDE ZELO COM A OBRA DO ESPÍRITO.\nCRIA EM MIM UM CORAÇÃO PURO\nE RENOVA-ME COM UM ESPÍRITO RETO.'}]},
#    {'slide': '407',
#     'shapes': [{'text': 'CORO (2X)\nO SENHOR SALVA, O SENHOR LIVRA, \nNÃO COM ESPADA, POIS DELE É A GUERRA; \nTOMA O CAJADO, DESCE AO RIBEIRO, \nDIANTE DA PELEJA O SENHOR É CONTIGO.\n\nFINAL: DIANTE DA PELEJA O SENHOR É CONTIGO.'},
#      {'text': 'Índice'}]}]},
#  {'slides': [{'slide': '408',
#     'shapes': [{'text': 'CANTE ALELUIA'},
#      {'text': 'CANTE ALELUIA, CANTE ALELUIA \nCANTE ALELUIA, CANTE ALELUIA \nCANTE AO SENHOR.\n\nPORQUE ELE É O REI DA GLÓRIA\nELE É O REI DA GLÓRIA'},
#      {'auto_shape': 'RIGHT_BRACE',
#       'shape': 'AUTO_SHAPE',
#       'height': 1305793,
#       'top': 2717750,
#       'text': ''},
#      {'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 646012,
#       'top': 3089499,
#       'text': 'BIS'}]},
#    {'slide': '409',
#     'shapes': [{'text': 'CANTE ALELUIA, CANTE ALELUIA\nCANTE AO SENHOR.\n\nPORQUE ELE FAZ MARAVILHAS,\nELE FAZ MARAVILHAS'},
#      {'auto_shape': 'RIGHT_BRACE',
#       'shape': 'AUTO_SHAPE',
#       'height': 1305793,
#       'top': 1657288,
#       'text': ''},
#      {'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 646012,
#       'top': 2047411,
#       'text': 'BIS'}]},
#    {'slide': '410',
#     'shapes': [{'text': 'CANTE ALELUIA, CANTE ALELUIA\nCANTE AO SENHOR.\n\nPORQUE ELE É O DEUS QUE NOS OUVE,\nELE NOS OUVE.'},
#      {'auto_shape': 'RIGHT_BRACE',
#       'shape': 'AUTO_SHAPE',
#       'height': 1305793,
#       'top': 1657288,
#       'text': ''},
#      {'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 646012,
#       'top': 2047411,
#       'text': 'BIS'}]},
#    {'slide': '411',
#     'shapes': [{'text': 'CANTE ALELUIA, CANTE ALELUIA\nCANTE AO SENHOR.\n\nCANTE ALELUIA AO SENHOR,\nCANTE ALELUIA AO SENHOR!'},
#      {'text': 'Índice'},
#      {'auto_shape': 'RECTANGLE',
#       'shape': 'AUTO_SHAPE',
#       'height': 646012,
#       'top': 2047411,
#       'text': 'BIS'},
#      {'auto_shape': 'RIGHT_BRACE',
#       'shape': 'AUTO_SHAPE',
#       'height': 1305793,
#       'top': 1657288,
#       'text': ''}]}]},
#  {'slides': [{'slide': '412',
#     'shapes': [{'text': 'Oração do pastor'},
#      {'text': 'ERA AINDA TÃO NOVO, \nTU ME DESTE UM CAJADO, \nRESISTI RECEBÊ-LO\nPOR TEMOR DOS TEUS LÁBIOS\nHOJE LOUVO AO SENHOR!\nPOR POSSUÍ-LO AINDA COMIGO'}]},
#    {'slide': '413',
#     'shapes': [{'text': 'A PESAR DOS DIAS PASSADOS,\nEU ME SINTO FORTALECIDO \nPELO TEU AMOR \nE, EMBEBECIDO PELO AGIR DO TEU ESPÍRITO SOBRE MIM.'}]},
#    {'slide': '414',
#     'shapes': [{'text': 'CORO\nEIS-ME AQUI, SENHOR! \nEIS-ME AQUI, SENHOR BENDITO, \nEIS-ME AQUI, SENHOR! \n\nFINAL: EIS-ME AQUI, SENHOR!'},
#      {'text': 'Índice'}]}]},
#  {'slides': [{'slide': '415',
#     'shapes': [{'text': 'FORTE DEUS'},
#      {'text': 'FORTE DEUS, TODO PODEROSO\nA TUA PAZ EXCEDE TODO ENTENDIMENTO\nE A TUA PAZ GUARDARÁ OS NOSSOS CORAÇÕES\nE OS NOSSOS PENSAMENTOS\nEM CRISTO JESUS'}]},
#    {'slide': '416',
#     'shapes': [{'text': 'TODO PODEROSO, DEUS,\nDEUS FORTE, MAGNIFICENTE, EMANUEL,\nTUA GLÓRIA ENCHERÁ TODA TERRA;\nINCOMPARÁVEIS SÃO AS TUAS OBRAS,\nÓ DEUS, GRANDIOSO ÉS!\nNOS ENSINASTE, ENTÃO,\nTUDO O QUE É VERDADEIRO, NISSO PENSAI.\nO QUE É PURO E JUSTO,\nSE HÁ ALGUM LOUVOR, NISSO PENSAI.'}]},
#    {'slide': '417',
#     'shapes': [{'text': 'À SOMBRA DA MORTE ANDÁVAMOS PERDIDOS,\nE EM MEIO ÀS TREVAS RESPLANDECEU A LUZ.\nE AGORA LIBERTOS EXULTAREMOS EM CRISTO,\nQUE VEIO AO MUNDO PARA SALVAÇÃO NOS DAR.'}]},
#    {'slide': '418',
#     'shapes': [{'text': 'UM MENINO NOS NASCEU; E SOBRE OS SEUS OMBROS\nO PRINCIPADO ESTÁ; E SE CHAMARÁ O SEU NOME:\nCONSELHEIRO, MARAVILHOSO, FORTE DEUS \nE PRÍNCIPE DA PAZ. DA ETERNIDADE É PAI, \nE O PRINCIPADO ETERNO SUBSISTIRÁ\nCOM JUÍZO E COM JUSTIÇA, \nFIRMADO AGORA E ETERNAMENTE,\nPELO ZELO DO SENHOR.'}]},
#    {'slide': '419',
#     'shapes': [{'text': 'TODO PODEROSO DEUS.\nDEUS FORTE, MAGNIFICENTE, EMANUEL,\nTUA GLÓRIA ENCHERÁ TODA TERRA;\nINCOMAPARÁVEIS SÃO TUAS OBRAS,\nGRANDIOSO ÉS.'},
#      {'text': 'Índice'}]}]},
#  {'slides': [{'slide': '420', 'shapes': []}]}]

# %%
erros_conhecidos = [
    "ABENÇOA-NOS SENHOR, DERRAMA SOBRE NÓS TUA PAZ ABENÇOA-NOS SENHOR, DERRAMA SOBRE NÓS TEU AMOR.",  # indice extra
    "MEU JESUS, SALVADOR,  OUTRO IGUAL NÃO HÁ. TODOS OS DIAS QUERO LOUVAR  AS MARAVILHAS DE TEU AMOR. CONSOLO, ABRIGO,  FORÇA E REFÚGIO É O SENHOR. COM TODO O MEU SER,  COM TUDO O QUE SOU,  SEMPRE TE ADORAREI.",  # pedaco de louvor
    "PODES CLAMAR, PODES CHORAR, EU ESTAREI PRONTO PRA TE AJUDAR, E SE O CORAÇÃO DESFALECER, CONFIA EM MIM SOU JESUS  E TE FAÇO VENCER.",  # pedaco de louvor
    "AO CORDEIRO GLÓRIA E HONRA,  SALVOS NÃO CESSEIS DE DAR. GLÓRIA, HONRA SEMPRE A DEUS ENTOAREI!  AMÉM!",  # indice extra
]
TAGS_LITERAIS = [
    "TODOS",
    "M",
    "H",
    "T",
    "BIS",
    "VARÕES",
    "SERVAS",
]
TAGS_CONTROLE = [
    "ÍNDICE",
    "CORO (2X)",
    "\n\nCORO",
    "CORO\n",
    "1X",
    "2X",
    "3X",
    "4X",
    "()",
    "(TODOS)",
    "(M)",
    "(H)",
    "(T)",
    "(BIS)",
    "(VARÕES)",
    "(SERVAS)",
    "REPETIR O LOUVOR",
    "REPETIR 1ª ESTROFE",
    "FINAL:",
    "BIS NO FINAL",
    "IGREJA CRISTÃ MARANATA",
    "ATUALIZAÇÃO",
    "\nINSTRUMENTOS",
]

# %%
import re


def return_possible_title(texts):
    possible_title = [
        text
        for text in texts
        if all(opt not in text.upper() for opt in TAGS_CONTROLE)
        and text.strip() != ""
        and text.upper() not in TAGS_LITERAIS
    ]
    if possible_title:
        min_string = min(possible_title, key=len)
        title_index = texts.index(min_string)
        title = min_string.upper().replace("\n", " ")
        if title not in erros_conhecidos:
            return title, title_index
    return None, None


def set_text_clean(texts_wo_title):
    texts_clean = [re.sub(r"\s+", " ", text) for text in texts_wo_title]
    texts_clean = [line for line in texts_clean if line not in TAGS_LITERAIS]
    new_texts_clean = []
    for line in texts_clean:
        for tag in TAGS_CONTROLE:
            line = line.upper().replace(tag, "")
        line = line.strip()
        if line:
            new_texts_clean.append(line)
    texts_clean = new_texts_clean
    # texts_clean = list(dict.fromkeys(texts_clean))
    texts_clean = " ".join(texts_clean)
    texts_clean = texts_clean.replace("\n", " ")
    # remove all double quotes
    texts_clean = texts_clean.replace("“", "")
    texts_clean = texts_clean.replace("”", "")
    texts_clean = texts_clean.replace('"', "")
    return texts_clean


def set_text_full(texts_wo_title):
    texts_full = [
        line
        for line in texts_wo_title
        if line.upper() != "ÍNDICE" and line.strip() != ""
    ]
    texts_full = "\n\n".join(texts_full)
    texts_full = texts_full.replace("\n\nBIS", "\nBIS")
    texts_full = texts_full.replace('"', "'")
    return texts_full


def return_number(title):
    if title:
        for word in title.split(" "):
            match = re.search(r"\d+", word)
            if match:
                return match.group()
    return "null"


def process_structure(praises):
    new_structure = []
    for praise in praises:
        texts = list(get_texts(praise))

        if not texts:
            continue

        # clean double or more spaces in string array
        texts = [text.replace("–", "-") for text in texts]

        title, title_index = return_possible_title(texts)
        numero = return_number(title)

        texts_wo_title = texts.copy()
        if title_index is not None:
            texts_wo_title.pop(title_index)

        texts_full = set_text_full(texts_wo_title)
        texts_clean = set_text_clean(texts_wo_title)

        new_structure.append(
            {
                "numero": numero,
                "nome": title if title is not None else "null",
                "texto": texts_full,
                "texto_limpo": texts_clean,
            }
        )

    return new_structure


new_structure = process_structure(praises)

new_structure
# Out:
# [{'numero': 'null',
#   'nome': 'SHEKINAH',
#   'texto': 'CORO\nÓ SENHOR, A TI CLAMO\nQUE NOS MOSTRES A TUA SHEKINAH;\nCOM TUA GLÓRIA ENCHE ESTE LUGAR,\nCOM TUA PRESENÇA, A TUA SHEKINAH.\n\nSENHOR, SEI QUE ME CONHECES,\nQUERO ANDAR EM TEU CAMINHO\nE ENCONTRAR O TEU FAVOR.\n\nSENHOR, SÓ TUA PRESENÇA \nPODE ME FAZER DESCANSAR, \nSE NÃO FORES COMIGO EU NÃO PROSSEGUIREI,\nSE ANDARES COMIGO O MUNDO SABERÁ QUE \nTE ENCONTREI, POIS DESTE MUNDO EU ME SEPAREI.\n\nCORO\nÓ SENHOR, A TI CLAMO\nQUE NOS MOSTRES A TUA SHEKINAH;\nCOM TUA GLÓRIA ENCHE ESTE LUGAR,\nCOM TUA PRESENÇA, A TUA SHEKINAH. \n\nINSTRUMENTOS\nBIS\n\nCORO\nÓ SENHOR, A TI CLAMO\nQUE NOS MOSTRES A TUA SHEKINAH;\nCOM TUA GLÓRIA ENCHE ESTE LUGAR,\nCOM TUA PRESENÇA, A TUA SHEKINAH.\n\nFINAL: SHEKINAH, SHEKINAH!',
#   'texto_limpo': 'CORO Ó SENHOR, A TI CLAMO QUE NOS MOSTRES A TUA SHEKINAH; COM TUA GLÓRIA ENCHE ESTE LUGAR, COM TUA PRESENÇA, A TUA SHEKINAH. SENHOR, SEI QUE ME CONHECES, QUERO ANDAR EM TEU CAMINHO E ENCONTRAR O TEU FAVOR. SENHOR, SÓ TUA PRESENÇA PODE ME FAZER DESCANSAR, SE NÃO FORES COMIGO EU NÃO PROSSEGUIREI, SE ANDARES COMIGO O MUNDO SABERÁ QUE TE ENCONTREI, POIS DESTE MUNDO EU ME SEPAREI. CORO Ó SENHOR, A TI CLAMO QUE NOS MOSTRES A TUA SHEKINAH; COM TUA GLÓRIA ENCHE ESTE LUGAR, COM TUA PRESENÇA, A TUA SHEKINAH. INSTRUMENTOS CORO Ó SENHOR, A TI CLAMO QUE NOS MOSTRES A TUA SHEKINAH; COM TUA GLÓRIA ENCHE ESTE LUGAR, COM TUA PRESENÇA, A TUA SHEKINAH.  SHEKINAH, SHEKINAH!'},
#  {'numero': 'null',
#   'nome': 'TORRE FORTE',
#   'texto': 'ESSAS LÁGRIMAS QUE ESCORREM DOS TEUS OLHOS\nSÓ JESUS É QUE PODE ENXUGÁ-LAS,\nSE TU VIVES TÃO SOZINHO, SEM PAZ, SEM AMOR,\nCRISTO QUER SER SEU AMIGO;\n\nELE JÁ LEVOU SOBRE SI \nNOSSAS DORES E OS NOSSOS PECADOS,\nFOI COM SANGUE INOCENTE \nQUE NÓS FOMOS COMPRADOS,\nHOJE SOMOS PARTE DO REINO DE DEUS.\n\nCORO\nTORRE FORTE (TORRE FORTE),\nDEUS CONOSCO (DEUS CONOSCO),\nPODEROSO EM OBRAS, PRÍNCIPE DOS EXÉRCITOS;\nO SENHOR SEMPRE VENCEU,\nNELE NÃO HÁ DERROTAS, \nELE É REI SOBRE TODOS OS REIS\n\nINSTRUMENTOS\n\nVEJO CRISTO SOBRE AS NUVENS TRIUNFANTE,\nEIS O BRADO DE VITÓRIA, NÓS VENCEMOS!\nOUÇO O TOQUE DA TROMBETA, \nA IGREJA VAI SUBINDO,\nANJOS E ARCANJOS NOS ESPERAM NO CÉU;\n\nALELUIA, NÓS CHEGAMOS AO FIM, \nOS REMIDOS QUE EM DEUS CONFIARAM,\nHÁ NO CÉU ALEGRIA, ALTO SOM DE LOUVOR,\nTODOS BENDIZENDO AO FILHO DE DEUS.\n\nCORO\nTORRE FORTE (TORRE FORTE),\nDEUS CONOSCO (DEUS CONOSCO),\nPODEROSO EM OBRAS, PRÍNCIPE DOS EXÉRCITOS;\nO SENHOR SEMPRE VENCEU,\nNELE NÃO HÁ DERROTAS, \nELE É REI SOBRE TODOS OS REIS\n\nFINAL:\nO SENHOR SEMPRE VENCEU, \nNELE NÃO HÁ DERROTAS, \nELE É REI SOBRE TODOS OS REIS,\nREI SOBRE TODOS OS REIS.',
#   'texto_limpo': 'ESSAS LÁGRIMAS QUE ESCORREM DOS TEUS OLHOS SÓ JESUS É QUE PODE ENXUGÁ-LAS, SE TU VIVES TÃO SOZINHO, SEM PAZ, SEM AMOR, CRISTO QUER SER SEU AMIGO; ELE JÁ LEVOU SOBRE SI NOSSAS DORES E OS NOSSOS PECADOS, FOI COM SANGUE INOCENTE QUE NÓS FOMOS COMPRADOS, HOJE SOMOS PARTE DO REINO DE DEUS. CORO TORRE FORTE (TORRE FORTE), DEUS CONOSCO (DEUS CONOSCO), PODEROSO EM OBRAS, PRÍNCIPE DOS EXÉRCITOS; O SENHOR SEMPRE VENCEU, NELE NÃO HÁ DERROTAS, ELE É REI SOBRE TODOS OS REIS INSTRUMENTOS VEJO CRISTO SOBRE AS NUVENS TRIUNFANTE, EIS O BRADO DE VITÓRIA, NÓS VENCEMOS! OUÇO O TOQUE DA TROMBETA, A IGREJA VAI SUBINDO, ANJOS E ARCANJOS NOS ESPERAM NO CÉU; ALELUIA, NÓS CHEGAMOS AO FIM, OS REMIDOS QUE EM DEUS CONFIARAM, HÁ NO CÉU ALEGRIA, ALTO SOM DE LOUVOR, TODOS BENDIZENDO AO FILHO DE DEUS. CORO TORRE FORTE (TORRE FORTE), DEUS CONOSCO (DEUS CONOSCO), PODEROSO EM OBRAS, PRÍNCIPE DOS EXÉRCITOS; O SENHOR SEMPRE VENCEU, NELE NÃO HÁ DERROTAS, ELE É REI SOBRE TODOS OS REIS O SENHOR SEMPRE VENCEU, NELE NÃO HÁ DERROTAS, ELE É REI SOBRE TODOS OS REIS, REI SOBRE TODOS OS REIS.'},
#  {'numero': 'null',
#   'nome': 'VARÃO DE GUERRA É O SENHOR',
#   'texto': 'VARÃO DE GUERRA É O SENHOR \nQUE VAI À FRENTE DO SEU POVO\nNAS PELEJAS DA ALMA, NAS PROVAÇÕES\nNAS LUTAS CONTRA OS NOSSOS ADVERSÁRIOS.\n\nVARÃO DE GUERRA É O SENHOR \nQUE ERGUE A SUA ESPADA \nE COM LABAREDAS DE FOGO\nTOCA NOS SEUS MINISTROS \nE OS TORNA CAPAZES PARA AS PELEJAS.\n\nESTE É O MEU DEUS, \nSOBERANO EM FORÇA E PODER, \nO ÚNICO QUE SE ASSENTA \nNO TRONO DA GLÓRIA E QUE REINARÁ\nETERNAMENTE;\n\nESTE É O MEU DEUS, \nSOBERANO EM FORÇA E PODER, \nJUSTO E CUMPRIDOR DA SUA PALAVRA, \nQUE NOS PROMETEU UM REI, JESUS,\nPARA REINAR SOBRE NÓS NA CIDADE SANTA\n\nFINAL: ETERNAMENTE.',
#   'texto_limpo': 'VARÃO DE GUERRA É O SENHOR QUE VAI À FRENTE DO SEU POVO NAS PELEJAS DA ALMA, NAS PROVAÇÕES NAS LUTAS CONTRA OS NOSSOS ADVERSÁRIOS. VARÃO DE GUERRA É O SENHOR QUE ERGUE A SUA ESPADA E COM LABAREDAS DE FOGO TOCA NOS SEUS MINISTROS E OS TORNA CAPAZES PARA AS PELEJAS. ESTE É O MEU DEUS, SOBERANO EM FORÇA E PODER, O ÚNICO QUE SE ASSENTA NO TRONO DA GLÓRIA E QUE REINARÁ ETERNAMENTE; ESTE É O MEU DEUS, SOBERANO EM FORÇA E PODER, JUSTO E CUMPRIDOR DA SUA PALAVRA, QUE NOS PROMETEU UM REI, JESUS, PARA REINAR SOBRE NÓS NA CIDADE SANTA  ETERNAMENTE.'},
#  {'numero': 'null',
#   'nome': 'AINDA HÁ TEMPO',
#   'texto': 'COMO É FORTE OUVIR COMO SERÁ O FIM; \nO MOMENTO CHEGARÁ, \nO CLAMOR DA MEIA-NOITE SE OUVIRÁ.\n\nA IGREJA FIEL PREPARADA ESTÁ \nE A IGREJA INFIEL, \nSUA OPORTUNIDADE ACABARÁ.\n\nAINDA HÁ TEMPO, \nJESUS CRISTO NÃO VOLTOU, \nAINDA HÁ TEMPO \nDO SEU SONO DESPERTAR. \n\nAINDA HÁ TEMPO, \nTEMPO DE SE ARREPENDER, \nTEMPO DE BUSCAR A DEUS, \nDE BATER À PORTA E ELA SE ABRIRÁ\n\nAINDA HÁ TEMPO DO AZEITE IR COMPRAR, \nAINDA HÁ TEMPO, TEMPO DE SANTIFICAR; AINDA HÁ TEMPO DA CANDEIA SE ENCHER, DO ESPOSO ENCONTRAR E COM ELE
nQUE É, SENHOR, NA TUA PRESENÇA, \nO LUGAR DE ONDE EU NÃO MAIS SAIREI!\n\nFINAL: \nQUE É, SENHOR, NA TUA PRESENÇA, \nO LUGAR DE ONDE EU NÃO MAIS SAIREI!',
#   'texto_limpo': 'EM CAMINHOS DE DOR EU ANDAVA, EM DESOBEDIÊNCIA AO SENHOR; EU ME ASSENTAVA E CHORAVA, ME LEMBRANDO COMO EU ERA FELIZ. QUEM JÁ FOI ESCRAVO UM DIA, SABE QUE NÃO HÁ ALEGRIA EM CANTAR LOUVORES DISTANTE, DISTANTE DA CASA DO PAI. COMO EU PODERIA CANTAR ALI? POIS TU ÉS MINHA MAIOR ALEGRIA; SE NÃO FOR PRA TI, PRA NINGUÉM MAIS SERÁ. TUA PRESENÇA, Ó DEUS, QUERO TODOS OS DIAS! MEU LOUVOR É SÓ PRA TI, SÓ PRA TI! HAVERÁ O DIA DA VITÓRIA, A VITÓRIA FINAL, QUANDO SERÁ DESTRUÍDO E ESQUECIDO O MAL, O INIMIGO DO SENHOR, AQUELE QUE AOS HOMENS TROUXE TANTA DOR, TANTA DOR. HOJE EU CANTO AO SENHOR, VOLTEI, NÃO ME ESQUECEREI QUE É, SENHOR, NA TUA PRESENÇA, O LUGAR DE ONDE EU NÃO MAIS SAIREI! QUE É, SENHOR, NA TUA PRESENÇA, O LUGAR DE ONDE EU NÃO MAIS SAIREI!'},
#  {'numero': 'null',
#   'nome': 'A MELHOR COISA',
#   'texto': 'DE TANTAS COISAS \nQUE ANDEI FAZENDO,\nDE QUASE TODAS ME ARREPENDI.\nMAS HOUVE UMA ESPECIAL,\nFOI A MAIS CERTA QUE ESCOLHI.\n\nCORO\nA MELHOR COISA QUE EU JÁ FIZ\nEM TODA A MINHA VIDA, \nPOR ISSO SOU FELIZ EM \nACEITAR JESUS, SINCERAMENTE FOI\nA MELHOR COISA QUE EU JÁ FIZ.\n\nCOISAS ERRADAS ANDEI FAZENDO\nNA CONDIÇÃO DE PECADOR,\nMAS QUANDO ACHEI-ME DESFALECENDO,\nTOMEI A DECISÃO QUE ME SALVOU.\n\nCORO (2X)\nA MELHOR COISA QUE EU JÁ FIZ\nEM TODA A MINHA VIDA, \nPOR ISSO SOU FELIZ EM \nACEITAR JESUS, SINCERAMENTE FOI\nA MELHOR COISA QUE EU JÁ FIZ.',
#   'texto_limpo': 'DE TANTAS COISAS QUE ANDEI FAZENDO, DE QUASE TODAS ME ARREPENDI. MAS HOUVE UMA ESPECIAL, FOI A MAIS CERTA QUE ESCOLHI. CORO A MELHOR COISA QUE EU JÁ FIZ EM TODA A MINHA VIDA, POR ISSO SOU FELIZ EM ACEITAR JESUS, SINCERAMENTE FOI A MELHOR COISA QUE EU JÁ FIZ. COISAS ERRADAS ANDEI FAZENDO NA CONDIÇÃO DE PECADOR, MAS QUANDO ACHEI-ME DESFALECENDO, TOMEI A DECISÃO QUE ME SALVOU. A MELHOR COISA QUE EU JÁ FIZ EM TODA A MINHA VIDA, POR ISSO SOU FELIZ EM ACEITAR JESUS, SINCERAMENTE FOI A MELHOR COISA QUE EU JÁ FIZ.'},
#  {'numero': 'null',
#   'nome': 'BARNABÉ, HOMEM DE DEUS',
#   'texto': 'NÃO FICA BEM A GENTE PASSAR BEM E O OUTRO CARESTIA, AINDA MAIS QUANDO SE SABE O QUE FAZER E NÃO SE FAZ. COMO FRUTO DO AMOR DE CRISTO, FRUTO DO SEU COMPROMISSO, VENDEU UM HOMEM O QUE TINHA E REPARTIU.\n\nCORO\nERA SEU NOME BARNABÉ, NATURAL DE CHIPRE,\nTAMBÉM CHAMADO DE JOSÉ DA CONSOLAÇÃO,\nHOMEM BOM E PIEDOSO, CHEIO DE TEMOR E FÉ,\nHOMEM DE DEUS.\n\nE QUANDO SAULO CONVERTEU-SE A CRISTO LHE FALTOU AMIGO,ALGUÉM QUE FOSSE COMPANHEIRO,\nFONTE DE CONSOLO E ABRIGO. COMO FRUTO DO AMOR DE CRISTO, FRUTO DO SEU COMPROMISSO, FOI UM HOMEM PROCURÁ-LO, DANDO-LHE A MÃO.\n\nCORO\nERA SEU NOME BARNABÉ, NATURAL DE CHIPRE,\nTAMBÉM CHAMADO DE JOSÉ DA CONSOLAÇÃO,\nHOMEM BOM E PIEDOSO, CHEIO DE TEMOR E FÉ,\nHOMEM DE DEUS.\n\nE QUANDO A IGREJA SE ESPALHOU POR TODO CANTO QUE HAVIA, POR PROVIDÊNCIA, SIM,\nPOR MÃO DE DEUS CHEGOU A ANTIOQUIA.\nPRECISANDO DE UM PASTOR DE ALMAS, \nMESMO DE UM PASTOR DE HOMENS, FORAM PROCURAR AQUELE QUE DEUS PREPAROU.\n\nCORO\nERA SEU NOME BARNABÉ, NATURAL DE CHIPRE,\nTAMBÉM CHAMADO DE JOSÉ DA CONSOLAÇÃO,\nHOMEM BOM E PIEDOSO, CHEIO DE TEMOR E FÉ,\nHOMEM DE DEUS.',
#   'texto_limpo': 'NÃO FICA BEM A GENTE PASSAR BEM E O OUTRO CARESTIA, AINDA MAIS QUANDO SE SABE O QUE FAZER E NÃO SE FAZ. COMO FRUTO DO AMOR DE CRISTO, FRUTO DO SEU COMPROMISSO, VENDEU UM HOMEM O QUE TINHA E REPARTIU. CORO ERA SEU NOME BARNABÉ, NATURAL DE CHIPRE, TAMBÉM CHAMADO DE JOSÉ DA CONSOLAÇÃO, HOMEM BOM E PIEDOSO, CHEIO DE TEMOR E FÉ, HOMEM DE DEUS. E QUANDO SAULO CONVERTEU-SE A CRISTO LHE FALTOU AMIGO,ALGUÉM QUE FOSSE COMPANHEIRO, FONTE DE CONSOLO E ABRIGO. COMO FRUTO DO AMOR DE CRISTO, FRUTO DO SEU COMPROMISSO, FOI UM HOMEM PROCURÁ-LO, DANDO-LHE A MÃO. E QUANDO A IGREJA SE ESPALHOU POR TODO CANTO QUE HAVIA, POR PROVIDÊNCIA, SIM, POR MÃO DE DEUS CHEGOU A ANTIOQUIA. PRECISANDO DE UM PASTOR DE ALMAS, MESMO DE UM PASTOR DE HOMENS, FORAM PROCURAR AQUELE QUE DEUS PREPAROU.'},
#  {'numero': 'null',
#   'nome': 'COMO AGRADECER (MEU TRIBUTO)',
#   'texto': 'COMO AGRADECER, PELO BEM \nQUE TENS FEITO A MIM? \nQUE VEM DEMONSTRAR QUANTO \nAMOR TU TENS, Ó DEUS, POR MIM;\n\nAS VOZES DE MILHÕES DE ANJOS, \nNÃO PODERIAM EXPRESSAR, \nA GRATIDÃO DO MEU PEQUENO\nSER, QUE SÓ PERTENCE A TI.\n\nA DEUS DEMOS GLÓRIA (3X)\nQUE POR NÓS TANTO FEZ;\nFOI NA CRUZ QUE SALVOU-ME,\nSEU PODER RESTAUROU-ME,\nA DEUS DEMOS GLÓRIA, \nQUE POR NÓS TANTO FEZ.\n\nFOI NA CRUZ QUE SALVOU-ME,\nSEU PODER RESTAUROU-ME,\nA DEUS DEMOS GLÓRIA, \nQUE POR NÓS TANTO FEZ.\n\nQUERO VIVER AQUI \nPARA ADORAR-TE, MEU SENHOR,\nE SE SURGIR UM LOUVOR\nAO CALVÁRIO SEJA, SIM, SEJA, SIM.\n\nFOI NA CRUZ QUE SALVOU-ME,\nSEU PODER RESTAUROU-ME,\nA DEUS DEMOS GLÓRIA, \nQUE POR NÓS TANTO FEZ.',
#   'texto_limpo': 'COMO AGRADECER, PELO BEM QUE TENS FEITO A MIM? QUE VEM DEMONSTRAR QUANTO AMOR TU TENS, Ó DEUS, POR MIM; AS VOZES DE MILHÕES DE ANJOS, NÃO PODERIAM EXPRESSAR, A GRATIDÃO DO MEU PEQUENO SER, QUE SÓ PERTENCE A TI. A DEUS DEMOS GLÓRIA  QUE POR NÓS TANTO FEZ; FOI NA CRUZ
IM MINH’ALMA A DEUS PROCURA, POIS ELE ME CONDUZ. É CERTO QUE PROVADO SOU, PELO CAMINHO A PROSSEGUIR, PORÉM EU SEI QUE TU BEM PERTO ESTÁS. QUANDO HEI DE IR, SENHOR, NÃO SEI, PARA O TEU SANTO LAR, SINTO PORÉM TUA VOZ CHAMAR, EM BREVE PARTIREI. TUDO O QUE DEUS FIZER É BOM, A NOITE CLARA FICARÁ NO ETERNO LAR DE DEUS. AMÉM (5X)'},
#  {'numero': 'null',
#   'nome': 'DEUS PREPAROU',
#   'texto': 'DEUS PREPAROU UMA CIDADE \nPARA SUA IGREJA FIEL.\nNESTA CIDADE NÃO HAVERÁ DOR,\nPOIS ELE NÃO PERMITIRÁ.\nSEREMOS TIRADOS DESTE \nMUNDO CRUEL, PARA \nMORARMOS COM ELE NO CÉU.\n\nCORO\nEU QUERO ENTRAR NO CÉU COM JESUS,\nE CONTEMPLAR AS MANSÕES \nQUE DEUS PREPAROU.\nQUERO ANDAR NAS RUAS DE OURO\nE OUVIR A VOZ DE DEUS \nO MEU NOME CHAMAR.\n\nOUVE A VOZ DO REDENTOR, \nELE QUER HOJE SALVAR, \nQUER LIBERTAR E PERDOAR, \nTUAS FERIDAS CURAR E NÃO TARDARÁ.\nCRISTO VEM NOS BUSCAR, \nENTREGA TUA VIDA E ELE TE LEVARÁ.\n\nCORO\nEU QUERO ENTRAR NO CÉU COM JESUS,\nE CONTEMPLAR AS MANSÕES \nQUE DEUS PREPAROU.\nQUERO ANDAR NAS RUAS DE OURO\nE OUVIR A VOZ DE DEUS \nO MEU NOME CHAMAR.',
#   'texto_limpo': 'DEUS PREPAROU UMA CIDADE PARA SUA IGREJA FIEL. NESTA CIDADE NÃO HAVERÁ DOR, POIS ELE NÃO PERMITIRÁ. SEREMOS TIRADOS DESTE MUNDO CRUEL, PARA MORARMOS COM ELE NO CÉU. CORO EU QUERO ENTRAR NO CÉU COM JESUS, E CONTEMPLAR AS MANSÕES QUE DEUS PREPAROU. QUERO ANDAR NAS RUAS DE OURO E OUVIR A VOZ DE DEUS O MEU NOME CHAMAR. OUVE A VOZ DO REDENTOR, ELE QUER HOJE SALVAR, QUER LIBERTAR E PERDOAR, TUAS FERIDAS CURAR E NÃO TARDARÁ. CRISTO VEM NOS BUSCAR, ENTREGA TUA VIDA E ELE TE LEVARÁ.'},
#  {'numero': 'null',
#   'nome': 'EU NÃO POSSO FUGIR DO TEU ESPÍRITO',
#   'texto': 'EU NÃO POSSO FUGIR DO TEU ESPÍRITO, (SERVAS) \nNEM FICAR DISTANTE DO TEU AMOR; (VARÕES)\nSE EU SUBIR ATÉ OS CÉUS, \nSE AO ABISMO EU DESCER, \nSEI QUE ALI TU ESTÁS.\n\nMESMO SE EU TOMAR \nAS ASAS DA ALVORADA, \nTUA  MÃO AINDA ASSIM MEGUIARÁ, \nMESMO VINDO A NOITE ESCURA\nTUA LUZ BRILHARÁ, \nE COMIGO ESTARÁS.\n\nEU NÃO POSSO FUGIR DO TEU ESPÍRITO, (SERVAS) \nNEM FICAR DISTANTE DO TEU AMOR; (VARÕES)\nSE EU SUBIR ATÉ OS CÉUS, \nSE AO ABISMO EU DESCER, \nSEI QUE ALI TU ESTÁS.\n\nMESMO SE EU TOMAR \nAS ASAS DA ALVORADA, \nTUA  MÃO AINDA ASSIM MEGUIARÁ, \nMESMO VINDO A NOITE ESCURA\nTUA LUZ BRILHARÁ, \nE COMIGO ESTARÁS.',
#   'texto_limpo': 'EU NÃO POSSO FUGIR DO TEU ESPÍRITO,  NEM FICAR DISTANTE DO TEU AMOR;  SE EU SUBIR ATÉ OS CÉUS, SE AO ABISMO EU DESCER, SEI QUE ALI TU ESTÁS. MESMO SE EU TOMAR AS ASAS DA ALVORADA, TUA MÃO AINDA ASSIM MEGUIARÁ, MESMO VINDO A NOITE ESCURA TUA LUZ BRILHARÁ, E COMIGO ESTARÁS.'},
#  {'numero': 'null',
#   'nome': 'EXPIROU',
#   'texto': 'EXPIROU! NÃO MAIS PADECE\nDE DEUS PAI O FILHO AMADO,\nMAS O SOLO SE ESTREMECE \nCOM SEU SANGUE DERRAMADO.\n\nFOI ENTÃO QUE A DEUS BENDITO\nIMPLOROU O SALVADOR.\nEIS O AMOR VASTO, INFINITO, \nPELO POVO TRANSGRESSOR.\nENTREGOU A SUA VIDA! \nGRANDE PROVA DE AMOR!\nMESMO ALI CRUCIFICADO \nAMA A QUEM O CONDENOU!\n\nAOS SEUS PÉS EU VOU, ENQUANTO\nSOFRE ASSIM O CRISTO AMADO,\nPARA AO MENOS DAR-LHE O PRANTO,\nPOIS POR MIM DEU O SEU SANGUE.\nPARA AO MENOS DAR-LHE O PRANTO,\nPOIS POR MIM DEU O SEU SANGUE.',
#   'texto_limpo': 'EXPIROU! NÃO MAIS PADECE DE DEUS PAI O FILHO AMADO, MAS O SOLO SE ESTREMECE COM SEU SANGUE DERRAMADO. FOI ENTÃO QUE A DEUS BENDITO IMPLOROU O SALVADOR. EIS O AMOR VASTO, INFINITO, PELO POVO TRANSGRESSOR. ENTREGOU A SUA VIDA! GRANDE PROVA DE AMOR! MESMO ALI CRUCIFICADO AMA A QUEM O CONDENOU! AOS SEUS PÉS EU VOU, ENQUANTO SOFRE ASSIM O CRISTO AMADO, PARA AO MENOS DAR-LHE O PRANTO, POIS POR MIM DEU O SEU SANGUE. PARA AO MENOS DAR-LHE O PRANTO, POIS POR MIM DEU O SEU SANGUE.'},
#  {'numero': 'null',
#   'nome': 'ÉS UM REMIDO DE DEUS',
#   'texto': 'ÉS UM REMIDO DE DEUS.\nTU ÉS UM DOS MEUS,\nÉS AQUELE A QUEM ESCOLHI.\nUM DIA OUVIU MINHA VOZ,\nA VOZ DO FILHO DE DEUS,\nA FALAR: VEM AQUI ME SERVIR.\n\nSENHOR, NADA TENHO PRA TE OFERECER.\nSABES O QUE SOU, \nSABES QUEM SOU EU E O TEU \nQUERER EM MIM SERÁ O MEU PRAZER. \nTEUS MISTÉRIOS CONHECER, TUA OBRA\nREALIZAR, MINHA VIDA ENTREGAR.\n\nAS LUTAS VÊM, \nMAS AS VITÓRIAS TAMBÉM VÊM.\nE O TEU AMOR É MAIS FORTE,\nE SEM ELE NÃO ESTARIA AQUI.\nCOM TEU PODER, TUA GRAÇA, TUA LUZ\nSOU UM VENCEDOR, SOU UM SERVO,\nSOU VASO A SERVIÇO DO SENHOR.\nBIS\n\nFINAL: \nSOU VASO A SERVIÇO DO SENHOR.',
#   'texto': 'GUIA-ME PELAS DUNAS DO DESERTO\nGUIA-ME SINTO O TEU AMOR BEM PERTO\nGUIA-ME PELAS RUAS DESTA VIDA\nGUIA-ME ATÉ A TERRA PROMETIDA\n\nCORO\nGUIA-ME, DÁ-ME FORÇAS \nDE TI PRECISO TANTO ASSIM, \nUSA-ME, COMO QUISERES \nPORQUE TU ÉS PARTE DE MIM.\n\nINSTRUMENTOS\n\nÓ SENHOR, TEU CAJADO ME CONSOLA\nONDE FOR O MEU CÁLICE TRANSBORDA.\nFAZ-ME SER UM MANANCIAL DE ÁGUAS\nFAZ CORRER ÁGUAS VIVAS DE MINH’ALMA.\n\nCORO\nGUIA-ME, DÁ-ME FORÇAS \nDE TI PRECISO TANTO ASSIM, \nUSA-ME, COMO QUISERES \nPORQUE TU ÉS PARTE DE MIM.\n\nUSA-ME, COMO QUISERES,\nPORQUE TU ÉS PARTE DE MIM\n\nFINAL: PARTE DE MIM.',
#   'texto_limpo': 'GUIA-ME PELAS DUNAS DO DESERTO GUIA-ME SINTO O TEU AMOR BEM PERTO GUIA-ME PELAS RUAS DESTA VIDA GUIA-ME ATÉ A TERRA PROMETIDA CORO GUIA-ME, DÁ-ME FORÇAS DE TI PRECISO TANTO ASSIM, USA-ME, COMO QUISERES PORQUE TU ÉS PARTE DE MIM. INSTRUMENTOS Ó SENHOR, TEU CAJADO ME CONSOLA ONDE FOR O MEU CÁLICE TRANSBORDA. FAZ-ME SER UM MANANCIAL DE ÁGUAS FAZ CORRER ÁGUAS VIVAS DE MINH’ALMA. CORO GUIA-ME, DÁ-ME FORÇAS DE TI PRECISO TANTO ASSIM, USA-ME, COMO QUISERES PORQUE TU ÉS PARTE DE MIM. USA-ME, COMO QUISERES, PORQUE TU ÉS PARTE DE MIM  PARTE DE MIM.'},
#  {'numero': 'null',
#   'nome': 'GRANDE É O SENHOR, INCLINAI-VOS',
#   'texto': 'GRANDE É O SENHOR,\nINCLINAI-VOS TERRA HUMILDEMENTE.\nGRANDE É O SENHOR\nADORAÍ-O SEMPRE ALEGREMENTE.\nREGOZIJAI! DE CORAÇÃO!\nELE É O CRIADOR E NÓS A CRIAÇÃO.\n\nEIS QUE VEM DE SUA MÃO:\nO SOL, A LUA, ESTRELAS E PLANETAS\nJUSTO ÉS EM SUAS LEIS;\nTUFÕES ACALMAM, ONDAS OBEDECEM-NO\nSOSSEGA O MAR AO SEU MANDAR,\nMONTANHAS SE DESFARÃO,\nDESERTOS BROTARÃO BOAS COLHEITAS,\nA CRIAÇÃO LHE APRAZ, O SOL DIRIGE A\nLUA, ESCONDE A NOITE EM DIA FAZ.\n\nGRANDE É O SENHOR,\nO SOBERANO LÁ NOS CÉUS,\nE REI DOS REIS ONIPOTENTE E SANTO \nDEUS, GRANDE EM SEU PODER,\nE MASJESTOSO EM SEU SABER.\nSUA BONDADE É IMENSURAVÉL COMO \nO MAR, SEU AMPLO AMOR É \nINDISPENSÁVEL COMO O AR, \nSANTO É O SENHOR, \nVINDE ADORÁ-LO COM LOUVOR.\n\nHOSANA AO SALVADOR, \n(UNIDOS TODOS NÓS) VARÕES\nCANTEMOS EM LOUVOR,\n(CANTEMOS NUMA VOZ) VARÕES\nHOSANA AO NOSSO DEUS,\nHOSANA AO SALVADOR,\nHOSANA AO SENHOR,\nHOSANA AO SENHOR, AO SENHOR.',
#   'texto_limpo': 'GRANDE É O SENHOR, INCLINAI-VOS TERRA HUMILDEMENTE. GRANDE É O SENHOR ADORAÍ-O SEMPRE ALEGREMENTE. REGOZIJAI! DE CORAÇÃO! ELE É O CRIADOR E NÓS A CRIAÇÃO. EIS QUE VEM DE SUA MÃO: O SOL, A LUA, ESTRELAS E PLANETAS JUSTO ÉS EM SUAS LEIS; TUFÕES ACALMAM, ONDAS OBEDECEM-NO SOSSEGA O MAR AO SEU MANDAR, MONTANHAS SE DESFARÃO, DESERTOS BROTARÃO BOAS COLHEITAS, A CRIAÇÃO LHE APRAZ, O SOL DIRIGE A LUA, ESCONDE A NOITE EM DIA FAZ. GRANDE É O SENHOR, O SOBERANO LÁ NOS CÉUS, E REI DOS REIS ONIPOTENTE E SANTO DEUS, GRANDE EM SEU PODER, E MASJESTOSO EM SEU SABER. SUA BONDADE É IMENSURAVÉL COMO O MAR, SEU AMPLO AMOR É INDISPENSÁVEL COMO O AR, SANTO É O SENHOR, VINDE ADORÁ-LO COM LOUVOR. HOSANA AO SALVADOR, (UNIDOS TODOS NÓS) VARÕES CANTEMOS EM LOUVOR, (CANTEMOS NUMA VOZ) VARÕES HOSANA AO NOSSO DEUS, HOSANA AO SALVADOR, HOSANA AO SENHOR, HOSANA AO SENHOR, AO SENHOR.'},
#  {'numero': 'null',
#   'nome': 'HOJE EU DESCOBRI',
#   'texto': 'HOJE EU DESCOBRI A FORMA DE VIVER FELIZ, \nA CRISTO EU ENTREGUEI A MINHA VIDA E ESPEREI,\nA SOLUÇÃO DOS MEUS PROBLEMAS.\nE A RESPOSTA EM CRISTO EU ACHEI.\n\nHOJE EU VIVO BEM E A SUA PAZ EU ENCONTREI, \nO FARDO TÃO PESADO \nNO CAMINHO EU DEIXEI.\nELE O TOMOU EM SUA CRUZ E DISSE-ME: \n“FILHO MEU, TE ALIVIAREI”.\n\nCORO\nFICA SENHOR, EM MEU CORAÇÃO,\nMORA SENHOR, EM MEU CORAÇÃO.\n\nINSTRUMENTOS\n\nHOJE EU VIVO BEM E A SUA PAZ EU ENCONTREI, \nO FARDO TÃO PESADO \nNO CAMINHO EU DEIXEI.\nELE O TOMOU EM SUA CRUZ E DISSE-ME: \n“FILHO MEU, TE ALIVIAREI”.\n\nCORO\nFICA SENHOR, EM MEU CORAÇÃO,\nMORA SENHOR, EM MEU CORAÇÃO.',
#   'texto_limpo': 'HOJE EU DESCOBRI A FORMA DE VIVER FELIZ, A CRISTO EU ENTREGUEI A MINHA VIDA E ESPEREI, A SOLUÇÃO DOS MEUS PROBLEMAS. E A RESPOSTA EM CRISTO EU ACHEI. HOJE EU VIVO BEM E A SUA PAZ EU ENCONTREI, O FARDO TÃO PESADO NO CAMINHO EU DEIXEI. ELE O TOMOU EM SUA CRUZ E DISSE-ME: FILHO MEU, TE ALIVIAREI. CORO FICA SENHOR, EM MEU CORAÇÃO, MORA SENHOR, EM MEU CORAÇÃO. INSTRUMENTOS CORO FICA SENHOR, EM MEU CORAÇÃO, MORA SENHOR, EM MEU CORAÇÃO.'},
nTU ÉS TUDO QUE EU \nALMEJO MINHA VIDA E LUZ, \nCADA DIA TE DESEJO MAIS \nE MAIS, JESUS.\n\nINSTRUMENTOS\n\nCORO\nTU ÉS TUDO QUE EU \nALMEJO MINHA VIDA E LUZ, \nCADA DIA TE DESEJO MAIS \nE MAIS, JESUS.',
#   'texto_limpo': 'JUNTO A TI, QUERO ESTAR, EM TUA CASA HABITAR, TEU AMOR EM MIM SENTIR, TUA VOZ SUAVE OUVIR, JESUS! CORO TU ÉS TUDO QUE EU ALMEJO MINHA VIDA E LUZ, CADA DIA TE DESEJO MAIS E MAIS, JESUS. PELO ALTAR JÁ PASSEI E NO SANGUE ME LAVEI, POSSO AGORA TE ADORAR MINHA SEDE SACIAR, JESUS! TU ÉS TUDO QUE EU ALMEJO MINHA VIDA E LUZ, CADA DIA TE DESEJO MAIS E MAIS, JESUS. INSTRUMENTOS'},
#  {'numero': 'null',
#   'nome': 'LOUVAI A DEUS, SENHOR',
#   'texto': 'LOUVAI A DEUS, SENHOR, VINDE ADORÁ-LO,\nEM SEUS ATRIOS ENTOAI HINOS DE LOUVOR.\nLOUVAI A DEUS, SENHOR, VINDE ADORÁ-LO,\nEM SEUS ATRIOS ENTOAI HINOS DE LOUVOR.\n\nCÉUS ALEGRAI-VOS, TERRA EXULTAI,\nPERANTE A FACE DO SENHOR QUE VEM, ALELUIA.\nCÉUS ALEGRAI-VOS, TERRA EXULTAI,\nPERANTE A FACE DO SENHOR QUE VEM, ALELUIA.\n\nALELUIA, ALELUIA, ALELUIA, ALELUIA, ALELUIA, \nALELUIA, ALELUIA, ALELUIA, ALELUIA, ALELUIA.\n\nANJOS CANTAI, Ó NAÇÕES EXULTAI,\nPERANTE A FACE DO SENHOR QUE VEM, ALELUIA.\nANJOS CANTAI, Ó NAÇÕES EXULTAI,\nPERANTE A FACE DO SENHOR QUE VEM, ALELUIA.\n\nALELUIA, ALELUIA, ALELUIA, ALELUIA, ALELUIA, \nALELUIA, ALELUIA, ALELUIA, ALELUIA, ALELUIA.\n\nANJOS CANTAI, Ó NAÇÕES EXULTAI,\nPERANTE A FACE DO SENHOR QUE VEM, ALELUIA.\nANJOS CANTAI, Ó NAÇÕES EXULTAI,\nPERANTE A FACE DO SENHOR QUE VEM, ALELUIA.',
#   'texto_limpo': 'LOUVAI A DEUS, SENHOR, VINDE ADORÁ-LO, EM SEUS ATRIOS ENTOAI HINOS DE LOUVOR. LOUVAI A DEUS, SENHOR, VINDE ADORÁ-LO, EM SEUS ATRIOS ENTOAI HINOS DE LOUVOR. CÉUS ALEGRAI-VOS, TERRA EXULTAI, PERANTE A FACE DO SENHOR QUE VEM, ALELUIA. CÉUS ALEGRAI-VOS, TERRA EXULTAI, PERANTE A FACE DO SENHOR QUE VEM, ALELUIA. ALELUIA, ALELUIA, ALELUIA, ALELUIA, ALELUIA, ALELUIA, ALELUIA, ALELUIA, ALELUIA, ALELUIA. ANJOS CANTAI, Ó NAÇÕES EXULTAI, PERANTE A FACE DO SENHOR QUE VEM, ALELUIA. ANJOS CANTAI, Ó NAÇÕES EXULTAI, PERANTE A FACE DO SENHOR QUE VEM, ALELUIA. ALELUIA, ALELUIA, ALELUIA, ALELUIA, ALELUIA, ALELUIA, ALELUIA, ALELUIA, ALELUIA, ALELUIA. ANJOS CANTAI, Ó NAÇÕES EXULTAI, PERANTE A FACE DO SENHOR QUE VEM, ALELUIA. ANJOS CANTAI, Ó NAÇÕES EXULTAI, PERANTE A FACE DO SENHOR QUE VEM, ALELUIA.'},
#  {'numero': '150',
#   'nome': 'LOUVAI AO SENHOR (SALMO 150)',
#   'texto': 'ALELUIA (ALELUIA), ALELUIA (ALELUIA)\nALELUIA, ALELUIA, ALELUIA, ALELUIA.\n\nLOUVAI AO SENHOR NO SEU SANTUÁRIO,\nLOUVAI AO SENHOR NO FIRMAMENTO \nDO SEU PODER, LOUVAI AO NOSSO DEUS, \nPOR SEUS FEITOS PODEROSOS,\nLOUVAI-O CONFORME A SUA \nGRANDEZA.\n\nÓ LOUVAI AO SENHOR AO TOCAR DA TROMBETA,\nÓ LOUVAI AO SENHOR COM SALTÉRIO E COM HARPA,\nLOUVAI COM ADUFE, COM JÚBILO LOUVAI,\nLOUVAI-O COM ÓRGÃOS E CORDAS LOUVAI,\nLOUVAI AO SENHOR COM CÍMBALOS SONOROS,\nLOUVAI AO SENHOR COM CÍMBALOS RETUMBANTES,\nE TODO O SER QUE RESPIRA, E TODO O SER QUE \nRESPIRA LOUVE AO SENHOR, \nSIM LOUVE AO SENHOR.\n\nLOUVAI AO SENHOR NO SEU SANTUÁRIO,\nLOUVAI AO SENHOR NO FIRMAMENTO DO SEU PODER,\nLOUVAI AO NOSSO DEUS, POR SEUS FEITOS PODEROSOS,\nLOUVAI-O CONFORME A SUA GRANDEZA.\n\nÓ LOUVAI AO SENHOR AO TOCAR DA TROMBETA,\nO LOUVAI AO SENHOR COM SALTÉRIO E COM HARPA,\nLOUVAI COM ADUFE, COM JÚBILO LOUVAI,\nALELUIA, ALELUIA, ALELUIA, ALELUIA.',
#   'texto_limpo': 'ALELUIA (ALELUIA), ALELUIA (ALELUIA) ALELUIA, ALELUIA, ALELUIA, ALELUIA. LOUVAI AO SENHOR NO SEU SANTUÁRIO, LOUVAI AO SENHOR NO FIRMAMENTO DO SEU PODER, LOUVAI AO NOSSO DEUS, POR SEUS FEITOS PODEROSOS, LOUVAI-O CONFORME A SUA GRANDEZA. Ó LOUVAI AO SENHOR AO TOCAR DA TROMBETA, Ó LOUVAI AO SENHOR COM SALTÉRIO E COM HARPA, LOUVAI COM ADUFE, COM JÚBILO LOUVAI, LOUVAI-O COM ÓRGÃOS E CORDAS LOUVAI, LOUVAI AO SENHOR COM CÍMBALOS SONOROS, LOUVAI AO SENHOR COM CÍMBALOS RETUMBANTES, E TODO O SER QUE RESPIRA, E TODO O SER QUE RESPIRA LOUVE AO SENHOR, SIM LOUVE AO SENHOR. LOUVAI AO SENHOR NO SEU SANTUÁRIO, LOUVAI AO SENHOR NO FIRMAMENTO DO SEU PODER, LOUVAI AO NOSSO DEUS, POR SEUS FEITOS PODEROSOS, LOUVAI-O CONFORME A SUA GRANDEZA. Ó LOUVAI AO SENHOR AO TOCAR DA TROMBETA, O LOUVAI AO SENHOR COM SALTÉRIO E COM HARPA, LOUVAI COM ADUFE, COM JÚBILO LOUVAI, ALELUIA, ALELUIA, ALELUIA, ALELUIA.'},
#  {'numero': 'null',
#   'nome': 'MAIS PUREZA DÁ-ME',
#   'texto': 'MAIS PUREZA DÁ-ME,                       \nREJEIÇÃO AO MAL,                            \nMAIS CALMA NAS LUTAS,                       \nMAIS ALTO IDEAL;                              \nMAIS FÉ NO MEU MESTRE,                      \nMAIS CONSAGRAÇÃO,                       \nMAIS GOZO EM SERVI-LO,                   \nMAIS GRATA ORAÇÃO.\n\nMAIS PRUDENTE FAZE-ME,                  \nMAIS SÁBIO, SENHOR;                        \nMAIS FIRME EM CRISTO,                      \nMAIS FORÇAS NA DOR;                      \nMAIS RETO NA VIDA,                          \nMAIS TRISTE AO PECAR;                      \nMAIS HUMILDE FILHO,                        \nMAIS PRONTO EM AMAR.\n\nMAIS PURO FAZE-ME,                             \nMAIS SANTO EM JESUS;                           \nMAIS DO TEU DOMÍNIO,                            \nMAIS GOZO NA CRUZ.                          \nMAIS RICA ESPERANÇA,                       \nMAIS FÉ E PODER.                                \nMAIS ÂNSIA DO CÉU,                            \nMAIS VIDA EM TI.',
#   'texto_limpo': 'MAIS PUREZA DÁ-ME, REJEIÇÃO AO MAL, MAIS CALMA NAS LUTAS, MAIS ALTO IDEAL; MAIS FÉ NO MEU MESTRE, MAIS CONSAGRAÇÃO, MAIS GOZO EM SERVI-LO, MAIS GRATA ORAÇÃO. MAIS PRUDENTE FAZE-ME, MAIS SÁBIO, SENHOR; MAIS FIRME EM CRISTO, MAIS FORÇAS NA DOR; MAIS RETO NA VIDA, MAIS TRISTE AO PECAR; MAIS HUMILDE FILHO, MAIS PRONTO EM AMAR. MAIS PURO FAZE-ME, MAIS SANTO EM JESUS; MAIS DO TEU DOMÍNIO, MAIS GOZO NA CRUZ. MAIS RICA ESPERANÇA, MAIS FÉ E PODER. MAIS ÂNSIA DO CÉU, MAIS VIDA EM TI.'},
#  {'numero': 'null',
#   'nome': 'MAIS QUE MARAVILHOSO',
#   'texto': 'JESUS NOS PROMETEU UM\nCONSELHEIRO SER,\nO FORTE DEUS, PRÍNCIPE DA\nPAZ, E COMO UM PAI SERIA\nPARA DAR-NOS AMOR, TÃO\nGRANDE QUE NÃO CESSARÁ\nJAMAIS.\n\nSERVAS\n\nDESCOBRI QUE JESUS CRISTO\nÉ UM DEUS FIEL.\nO QUE NOS PROMETEU\nCUMPRIU ENFIM.\nENTÃO, A MEU JESUS DESEJO\nCONFESSAR O QUE ELE\nREPRESENTA PARA MIM.\n\nVARÕES\n\nCORO\nMARAVILHOSO DEUS,\nMUITO MAIS QUE MEU SER \nPOSSA IMAGINAR, MUITO MAIS DO QUE SEI.\nPOIS ELE É MAIS, BEM MUITO MAIS DO QUE SONHEI.\nNELE ENCONTREI TUDO QUE PROCURAVA\nO QUE PRECISAVA SÓ NELE ACHEI:\nMARAVILHOSO, MUITO MAIS PRA MIM;\nDEUS MILAGROSO É, SEMPRE SERÁ\nMARAVILHOSO DEUS,\nÉ O QUE CRISTO É PRA MIM.\n\nAO RELEMBRAR QUE UM DIA,\nO REI DA GLÓRIA EM FORMA\nDE UM HOMEM SE TORNOU,\nFELIZ ME FAZ POIS SEI\nQUANTO ME AMAS, AO\nPENSAR QUEM ELE É\nE QUEM EU SOU.\n\nVARÕES\n\nCORO\nMARAVILHOSO DEUS,\nMUITO MAIS QUE MEU SER POSSA\nIMAGINAR, MUITO MAIS DO QUE SEI.\nPOIS ELE É MAIS, BEM MUITO MAIS DO QUE SONHEI.\nNELE ENCONTREI TUDO QUE PROCURAVA \nO QUE PRECISAVA SÓ NELE ACHEI:\nMARAVILHOSO, MUITO MAIS PRA MIM;\nDEUS MILAGROSO É, SEMPRE SERÁ \nMARAVILHOSO DEUS,\nÉ O QUE CRISTO É PRA MIM.\n\nFINAL:\nNELE ENCONTREI TUDO QUE\nPROCURAVA, O QUE PRECISAVA SÓ\nNELE ACHEI: MARAVILOSO, MUITO MAIS, PRA MIM;\nDEUS MILAGROSO É, SEMPRE SERÁ\nMARAVILHOSO DEUS,\nPODEROSO DEUS É, SEMPRE SERÁ\nMARAVILHOSO DEUS, PODEROSO DEUS, \nÉ O QUE CRISTO É PRA MIM.\nMARAVILHOSO É PRA MIM, PRA MIM.',
#   'texto_limpo': 'JESUS NOS PROMETEU UM CONSELHEIRO SER, O FORTE DEUS, PRÍNCIPE DA PAZ, E COMO UM PAI SERIA PARA DAR-NOS AMOR, TÃO GRANDE QUE NÃO CESSARÁ JAMAIS. DESCOBRI QUE JESUS CRISTO É UM DEUS FIEL. O QUE NOS PROMETEU CUMPRIU ENFIM. ENTÃO, A MEU JESUS DESEJ
#  {'numero': 'null',
#   'nome': 'EM OBEDIÊNCIA, SERVI AO SENHOR',
#   'texto': 'EM OBEDIÊNCIA, SERVI AO SENHOR \nE EM HUMILDADE, BUSCAI AO SENHOR; \nDAS RIQUEZAS DO REINO DE DEUS, \nENCHEI O CORAÇÃO. \nE CHEIOS DO ESPÍRITO, \nNA BATALHA TEREIS VITÓRIA.\n\nCORO:\nO SENHOR SALVA, O SENHOR LIVRA, \nNÃO COM ESPADA, POIS DELE É A GUERRA; \nTOMA O CAJADO, DESCE AO RIBEIRO, \nDIANTE DA PELEJA O SENHOR É CONTIGO.\n\nPRUDENTEMENTE, ANDAI NO CAMINHO\nE TENDE ZELO COM A OBRA DO ESPÍRITO.\nCRIA EM MIM UM CORAÇÃO PURO\nE RENOVA-ME COM UM ESPÍRITO RETO.\n\nCORO (2X)\nO SENHOR SALVA, O SENHOR LIVRA, \nNÃO COM ESPADA, POIS DELE É A GUERRA; \nTOMA O CAJADO, DESCE AO RIBEIRO, \nDIANTE DA PELEJA O SENHOR É CONTIGO.\n\nFINAL: DIANTE DA PELEJA O SENHOR É CONTIGO.',
#   'texto_limpo': 'EM OBEDIÊNCIA, SERVI AO SENHOR E EM HUMILDADE, BUSCAI AO SENHOR; DAS RIQUEZAS DO REINO DE DEUS, ENCHEI O CORAÇÃO. E CHEIOS DO ESPÍRITO, NA BATALHA TEREIS VITÓRIA. CORO: O SENHOR SALVA, O SENHOR LIVRA, NÃO COM ESPADA, POIS DELE É A GUERRA; TOMA O CAJADO, DESCE AO RIBEIRO, DIANTE DA PELEJA O SENHOR É CONTIGO. PRUDENTEMENTE, ANDAI NO CAMINHO E TENDE ZELO COM A OBRA DO ESPÍRITO. CRIA EM MIM UM CORAÇÃO PURO E RENOVA-ME COM UM ESPÍRITO RETO. O SENHOR SALVA, O SENHOR LIVRA, NÃO COM ESPADA, POIS DELE É A GUERRA; TOMA O CAJADO, DESCE AO RIBEIRO, DIANTE DA PELEJA O SENHOR É CONTIGO.  DIANTE DA PELEJA O SENHOR É CONTIGO.'},
#  {'numero': 'null',
#   'nome': 'CANTE ALELUIA',
#   'texto': 'CANTE ALELUIA, CANTE ALELUIA \nCANTE ALELUIA, CANTE ALELUIA \nCANTE AO SENHOR.\n\nPORQUE ELE É O REI DA GLÓRIA\nELE É O REI DA GLÓRIA\nBIS\n\nCANTE ALELUIA, CANTE ALELUIA\nCANTE AO SENHOR.\n\nPORQUE ELE FAZ MARAVILHAS,\nELE FAZ MARAVILHAS\nBIS\n\nCANTE ALELUIA, CANTE ALELUIA\nCANTE AO SENHOR.\n\nPORQUE ELE É O DEUS QUE NOS OUVE,\nELE NOS OUVE.\nBIS\n\nCANTE ALELUIA, CANTE ALELUIA\nCANTE AO SENHOR.\n\nCANTE ALELUIA AO SENHOR,\nCANTE ALELUIA AO SENHOR!\nBIS',
#   'texto_limpo': 'FORTE DEUS, TODO PODEROSO A TUA PAZ EXCEDE TODO ENTENDIMENTO E A TUA PAZ GUARDARÁ OS NOSSOS CORAÇÕES E OS NOSSOS PENSAMENTOS EM CRISTO JESUS TODO PODEROSO, DEUS, DEUS FORTE, MAGNIFICENTE, EMANUEL, TUA GLÓRIA ENCHERÁ TODA TERRA; INCOMPARÁVEIS SÃO AS TUAS OBRAS, Ó DEUS, GRANDIOSO ÉS! NOS ENSINASTE, ENTÃO, TUDO O QUE É VERDADEIRO, NISSO PENSAI. O QUE É PURO E JUSTO, SE HÁ ALGUM LOUVOR, NISSO PENSAI. À SOMBRA DA MORTE ANDÁVAMOS PERDIDOS, E EM MEIO ÀS TREVAS RESPLANDECEU A LUZ. E AGORA LIBERTOS EXULTAREMOS EM CRISTO, QUE VEIO AO MUNDO PARA SALVAÇÃO NOS DAR. UM MENINO NOS NASCEU; E SOBRE OS SEUS OMBROS O PRINCIPADO ESTÁ; E SE CHAMARÁ O SEU NOME: CONSELHEIRO, MARAVILHOSO, FORTE DEUS E PRÍNCIPE DA PAZ. DA ETERNIDADE É PAI, E O PRINCIPADO ETERNO SUBSISTIRÁ COM JUÍZO E COM JUSTIÇA, FIRMADO AGORA E ETERNAMENTE, PELO ZELO DO SENHOR. TODO PODEROSO DEUS. DEUS FORTE, MAGNIFICENTE, EMANUEL, TUA GLÓRIA ENCHERÁ TODA TERRA; INCOMAPARÁVEIS SÃO TUAS OBRAS, GRANDIOSO ÉS.'}]

# %% [markdown]
# # Criar arquivo de inserção

# %%
import glob

files_json = glob.glob("slides_json\\*.json")
files_json
# Out:
# ['slides_json\\01.COLETANEA_IGREJAS_2022_TV-16.9_ADAPT.pptx.txt.json',
#  'slides_json\\03.COLETÂNEA DE CIAS_2021 TV_ADAPT.pptx.txt.json',
#  'slides_json\\Louvores Avulsos CIAs 2022 - COM ANIMAÇÃO_ADAPT.pptx.txt.json',
#  'slides_json\\LOUVORES AVULSOS_Rev_31.12.22_ADAPT.pptx.txt.json']

# %%
for index, file in enumerate(files_json):
    file_name = (
        "00"
        + str(index + 3)
        + "-"
        + file.split("\\")[1].split("pptx")[0].lower().replace(" ", "_")
        + "sql"
    )

    with open(file, "r") as f:
        louvores = json.load(f)

    louvores_estruturados = process_structure(louvores)
    with open("db\\migrations\\" + file_name, "w") as f:
        for hino in louvores_estruturados:
            text = (
                "INSERT INTO hino (numero, nome, texto, texto_limpo, coletanea_id, date_insert, date_update) VALUES ('"
                + hino["numero"]
                + "', '"
                + hino["nome"]
                + "', '"
                + hino["texto"].replace("\n", "\\n").replace("'", "''")
                + "', '"
                + hino["texto_limpo"].replace("'", "''")
                + "', "
                + str(index + 1)
                + ", CURRENT_TIMESTAMP, CURRENT_TIMESTAMP);\n"
            )
            f.write(text)
